# %%
# import dependencies 
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline
import seaborn as sns
import warnings
warnings.filterwarnings('ignore')
pd.set_option('display.height', 1000)
pd.set_option('display.max_rows', 100)
pd.set_option('display.max_columns', 100)
pd.set_option('display.width', 1000)

# display multiple print results on one line
from IPython.core.interactiveshell import InteractiveShell
InteractiveShell.ast_node_interactivity = "all"

# expands .describe with more info about the data set
import pandas_profiling

# sqlalchemy dependencies
import sqlalchemy
from sqlalchemy.ext.automap import automap_base
from sqlalchemy.orm import Session
from sqlalchemy import create_engine
from sqlalchemy import func
from sqlalchemy import inspect

from sqlalchemy.ext.declarative import declarative_base
from sqlalchemy import Column, Integer, String, Float, Text

# PyMySQL 
import pymysql
pymysql.install_as_MySQLdb()

# flask 
from flask import Flask, jsonify
# Out:
# height has been deprecated.

# %%
# Use SQLAlchemy create_engine to connect to database
engine = create_engine("sqlite:///bbb.sqlite")
conn = engine.connect()

# %%
# use SQLAlchemy automap_base() to reflect tables into classes and save references
# called sample_names, otu_des, sample_meta, frequency
Base = automap_base()

# %%
# use the base class to reflect the database tables
Base.prepare(engine, reflect=True)

# %%
Base.classes.keys()
# Out:
# ['otu', 'samples', 'samples_metadata']

# %%
# assign classes to variables
sample_names = Base.classes.samples
otu_des = Base.classes.otu
sample_meta = Base.classes.samples_metadata

# %%
# create a session
# a session means that you want to do something to your data
session = Session(engine)

# %%
inspector = inspect(engine)

# %%
# get table information
print (inspector.get_table_names())
# Out:
# ['otu', 'samples', 'samples_metadata']

# %%
# get col names for samples and stores in a tuple within a list
sample_name_col = inspector.get_columns('samples')

# %%
# prints list of sample names
sample_names_list = [item["name"] for item in sample_name_col]
del sample_names_list[0]

# %%
# prints list of sample_names
# sample_names_list

# %%
# return list of OTU descriptions
otu_results = session.query(otu_des.lowest_taxonomic_unit_found).all()

# stores otu results as a list
otu_results_list = list(np.ravel(otu_results))

# %%
# read Belly_Button_Biodiversity_Metadata
bbb_meta_df = pd.read_csv('Belly_Button_Biodiversity_Metadata.csv')

# %%
bbb_meta_df.head()
bbb_meta_df.shape
# Out:
#    SAMPLEID                      EVENT              ETHNICITY GENDER   AGE  WFREQ BBTYPE         LOCATION COUNTRY012 ZIP012 COUNTRY1319 ZIP1319  DOG  CAT  IMPSURFACE013     NPP013  MMAXTEMP013  PFC013 IMPSURFACE1319  NPP1319  MMAXTEMP1319  PFC1319
# 0       940  BellyButtonsScienceOnline              Caucasian      F  24.0    2.0      I      Beaufort/NC        usa  22306         usa   22306   no   no         8852.0  37.172222         54.5     NaN              1      NaN     33.990002     25.5
# 1       941                        NaN  Caucasian/Midleastern      F  34.0    1.0      I       Chicago/IL        NaN    NaN         NaN     NaN  NaN  NaN            NaN        NaN          NaN     NaN            NaN      NaN           NaN      NaN
# 2       943  BellyButtonsScienceOnline              Caucasian      F  49.0    1.0      I         Omaha/NE        NaN    NaN         NaN     NaN  NaN  NaN            NaN        NaN          NaN     NaN            NaN      NaN           NaN      NaN
# 3       944  BellyButtonsScienceOnline               European      M  44.0    1.0      I      NewHaven/CT        usa   7079         usa    8822   no  yes            NaN  35.816666         16.0     NaN              0   6567.0     32.403332     28.5
# 4       945  BellyButtonsScienceOnline              Caucasian      F  48.0    1.0      I  Philidelphia/PA        usa  84404         usa   96025   no   no            NaN  37.783333          4.0     NaN              0   5613.0     33.634445     24.0
# (153, 22)

# %%
# create new bbb meta_df with the following columns:
# AGE, BBTYPE, ETHNICITY, GENDER, LOCATION, SAMPLEID

bbb_meta_clean = bbb_meta_df[['AGE', 'BBTYPE', 'ETHNICITY',
                             'GENDER', 'LOCATION', 'SAMPLEID']]
bbb_meta_clean.head()
bbb_meta_clean.shape
# Out:
#     AGE BBTYPE              ETHNICITY GENDER         LOCATION  SAMPLEID
# 0  24.0      I              Caucasian      F      Beaufort/NC       940
# 1  34.0      I  Caucasian/Midleastern      F       Chicago/IL       941
# 2  49.0      I              Caucasian      F         Omaha/NE       943
# 3  44.0      I               European      M      NewHaven/CT       944
# 4  48.0      I              Caucasian      F  Philidelphia/PA       945
# (153, 6)

# %%
bbb_meta_dict = bbb_meta_clean.to_dict('index')

# %%
bbb_meta_dict
# Out:
# {0: {'AGE': 24.0,
#   'BBTYPE': 'I',
#   'ETHNICITY': 'Caucasian',
#   'GENDER': 'F',
#   'LOCATION': 'Beaufort/NC',
#   'SAMPLEID': 940},
#  1: {'AGE': 34.0,
#   'BBTYPE': 'I',
#   'ETHNICITY': 'Caucasian/Midleastern',
#   'GENDER': 'F',
#   'LOCATION': 'Chicago/IL',
#   'SAMPLEID': 941},
#  2: {'AGE': 49.0,
#   'BBTYPE': 'I',
#   'ETHNICITY': 'Caucasian',
#   'GENDER': 'F',
#   'LOCATION': 'Omaha/NE',
#   'SAMPLEID': 943},
#  3: {'AGE': 44.0,
#   'BBTYPE': 'I',
#   'ETHNICITY': 'European',
#   'GENDER': 'M',
#   'LOCATION': 'NewHaven/CT',
#   'SAMPLEID': 944},
#  4: {'AGE': 48.0,
#   'BBTYPE': 'I',
#   'ETHNICITY': 'Caucasian',
#   'GENDER': 'F',
#   'LOCATION': 'Philidelphia/PA',
#   'SAMPLEID': 945},
#  5: {'AGE': 42.0,
#   'BBTYPE': 'I',
#   'ETHNICITY': 'Caucasian',
#   'GENDER': 'F',
#   'LOCATION': 'Deerfield/MA',
#   'SAMPLEID': 946},
#  6: {'AGE': 49.0,
#   'BBTYPE': 'I',
#   'ETHNICITY': 'Caucasian',
#   'GENDER': 'M',
#   'LOCATION': 'ChapelHill/NC',
#   'SAMPLEID': 947},
#  7: {'AGE': 20.0,
#   'BBTYPE': 'I',
#   'ETHNICITY': 'Caucasian',
#   'GENDER': 'M',
#   'LOCATION': 'ChapelHill/NC',
#   'SAMPLEID': 948},
#  8: {'AGE': 51.0,
#   'BBTYPE': 'I',
#   'ETHNICITY': 'Caucasian',
#   'GENDER': 'F',
#   'LOCATION': 'Durham/NC',
#   'SAMPLEID': 949},
#  9: {'AGE': 51.0,
#   'BBTYPE': 'I',
#   'ETHNICITY': 'Caucasian',
#   'GENDER': 'M',
#   'LOCATION': 'NewYork/NY',
#   'SAMPLEID': 950},
#  10: {'AGE': 51.0,
#   'BBTYPE': 'I',
#   'ETHNICITY': 'Caucasian',
#   'GENDER': 'F',
#   'LOCATION': 'Seattle/WA',
#   'SAMPLEID': 952},
#  11: {'AGE': 38.0,
#   'BBTYPE': 'I',
#   'ETHNICITY': 'Caucasian',
#   'GENDER': 'F',
#   'LOCATION': 'Chicago/IL',
#   'SAMPLEID': 953},
#  12: {'AGE': 26.0,
#   'BBTYPE': 'I',
#   'ETHNICITY': 'Caucasian',
#   'GENDER': 'M',
#   'LOCATION': 'NewYork/NY',
#   'SAMPLEID': 954},
#  13: {'AGE': 27.0,
#   'BBTYPE': 'I',
#   'ETHNICITY': 'Caucasian',
#   'GENDER': 'F',
#   'LOCATION': 'NewYork/NY',
#   'SAMPLEID': 955},
#  14: {'AGE': 16.0,
#   'BBTYPE': 'I',
#   'ETHNICITY': 'Caucasian',
#   'GENDER': 'M',
#   'LOCATION': 'Jacksonville/NC',
#   'SAMPLEID': 956},
#  15: {'AGE': 43.0,
#   'BBTYPE': 'I',
#   'ETHNICITY': 'Caucasian',
#   'GENDER': 'M',
#   'LOCATION': 'Wilmington/NC',
#   'SAMPLEID': 958},
#  16: {'AGE': 40.0,
#   'BBTYPE': 'I',
#   'ETHNICITY': 'Caucasian',
#   'GENDER': 'M',
#   'LOCATION': 'Carrboro/NC',
#   'SAMPLEID': 959},
#  17: {'AGE': 48.0,
#   'BBTYPE': 'I',
#   'ETHNICITY': 'Caucasian',
#   'GENDER': 'M',
#   'LOCATION': 'Lexington/NC',
#   'SAMPLEID': 960},
#  18: {'AGE': 35.0,
#   'BBTYPE': 'i',
#   'ETHNICITY': 'Caucasian',
#   'GENDER': 'F',
#   'LOCATION': 'Edmonton,AB',
#   'SAMPLEID': 961},
#  19: {'AGE': 56.0,
#   'BBTYPE': 'i',
#   'ETHNICITY': 'Caucasian',
#   'GENDER': 'F',
#   'LOCATION': 'Washington,DC',
#   'SAMPLEID': 962},
#  20: {'AGE': 33.0,
#   'BBTYPE': 'I',
#   'ETHNICITY': 'Caucasian',
#   'GENDER': 'F',
#   'LOCATION': 'Ithaca/NY',
#   'SAMPLEID': 963},
#  21: {'AGE': 43.0,
#   'BBTYPE': 'I',
#   'ETHNICITY': 'Caucasian',
#   'GENDER': 'F',
#   'LOCATION': 'UK/London',
#   'SAMPLEID': 964},
#  22: {'AGE': 56.0,
#   'BBTYPE': 'I',
#   'ETHNICITY': 'Caucasian',
#   'GENDER': 'M',
#   'LOCATION': 'Needham/MA',
#   'SAMPLEID': 966},
#  23: {'AGE': 43.0,
#   'BBTYPE': 'I',
#   'ETHNICITY': 'Caucasian/Jewish',
#   'GENDER': 'F',
#   'LOCATION': 'ChapelHill/NC',
#   'SAMPLEID': 967},
#  24: {'AGE': 38.0,
#   'BBTYPE': 'I',
#   'ETHNICITY': 'Caucasian',
#   'GENDER': 'F',
#   'LOCATION': 'St.Louis/MI',
#   'SAMPLEID': 968},
#  25: {'AGE': 31.0,
#   'BBTYPE': 'I',
#   'ETHNICITY': 'Caucasian/Asian',
#   'GENDER': 'F',
#   'LOCATION': 'ChevyChase/MD',
#   'SAMPLEID': 969},
#  26: {'AGE': 42.0,
#   'BBTYPE': 'i',
#   'ETHNICITY': 'Caucasian',
#   'GENDER': 'F',
#   'LOCATION': 'SanDiego/CA',
#   'SAMPLEID': 970},
#  27: {'AGE': 36.0,
#   'BBTYPE': 'I',
#   'ETHNICITY': 'Asian(South)',
#   'GENDER': 'M',
#   'LOCATION': 'SantaBarbara/CA',
#   'SAMPLEID': 971},
#  28: {'AGE': 31.0,
#   'BBTYPE': 'I',
#   'ETHNICITY': 'Caucasian',
#   'GENDER': 'F',
#   'LOCATION': 'Charlotte/NC',
#   'SAMPLEID': 972},
#  29: {'AGE': 4.0,
#   'BBTYPE': 'I',
#   'ETHNICITY': 'Caucasian',
#   'GENDER': 'F',
#   'LOCATION': 'Charlotte/NC',
#   'SAMPLEID': 973},
#  30: {'AGE': 57.0,
#   'BBTYPE': 'I',
#   'ETHNICITY': 'Caucasian',
#   'GENDER': 'F',
#   'LOCATION': 'Raleigh/NC',
#   'SAMPLEID': 974},
#  31: {'AGE': 60.0,
#   'BBTYPE': 'I',
#   'ETHNICITY': 'Caucasian',
#   'GENDER': 'F',
#   'LOCATION': 'NewCanaan/CT',
#   'SAMPLEID': 975},
#  32: {'AGE': 21.0,
#   'BBTYPE': nan,
#   'ETHNICITY': 'Hispanic',
#   'GENDER': 'F',
#   'LOCATION': 'Durham/NC',
#   'SAMPLEID': 978},
#  33: {'AGE': 34.0,
#   'BBTYPE': 'I',
#   'ETHNICITY': 'Caucasian',
#   'GENDER': 'M',
#   'LOCATION': nan,
#   'SAMPLEID': 1233},
#  34: {'AGE': nan,
#   'BBTYPE': 'I',
#   'ETHNICITY': 'Caucasian',
#   'GENDER': 'F',
#   'LOCATION': nan,
#   'SAMPLEID': 1234},
#  35: {'AGE': 43.0,
#   'BBTYPE': nan,
#   'ETHNICITY': 'Caucasian',
#   'GENDER': 'F',
#   'LOCATION': nan,
#   'SAMPLEID': 1235},
#  36: {'AGE': 54.0,
#   'BBTYPE': nan,
#   'ETHNICITY': 'Caucasian',
#   'GENDER': 'F',
#   'LOCATION': nan,
#   'SAMPLEID': 1236},
#  37: {'AGE': 9.0,
#   'BBTYPE': 'i',
#   'ETHNICITY': 'Caucasian',
#   'GENDER': 'F',
#   'LOCATION': 'ChapelHill,NC',
#   'SAMPLEID': 1237},
#  38: {'AGE': 41.0,
#   'BBTYPE': 'i',
#   'ETHNICITY': 'Caucasian',
#   'GENDER': 'F',
#   'LOCATION': 'Raleigh,NC',
#   'SAMPLEID': 1238},
#  39: {'AGE': 44.0,
#   'BBTYPE': 'i',
#   'ETHNICITY': 'Caucasian',
#   'GENDER': 'F',
#   'LOCATION': 'Raleigh,NC',
#   'SAMPLEID': 1242},
#  40: {'AGE': 49.0,
#   'BBTYPE': 'i',
#   'ETHNICITY': 'Caucasian',
#   'GENDER': 'M',
#   'LOCATION': 'Raleigh,NC',
#   'SAMPLEID': 1243},
#  41: {'AGE': 2.0,
#   'BBTYPE': nan,
#   'ETHNICITY': 'Caucasian',
#   'GENDER': 'F',
#   'LOCATION': 'Atlanta,GA',
#   'SAMPLEID': 1246},
#  42: {'AGE': 24.0,
#   'BBTYPE': 'i',
#   'ETHNICITY': 'Caucasian',
#   'GENDER': 'M',
#   'LOCATION': 'Voss,NC',
#   'SAMPLEID': 1253},
#  43: {'AGE': 1.0,
#   'BBTYPE': 'o',
#   'ETHNICITY': 'Caucasian',
#   'GENDER': 'F',
#   'LOCATION': 'Voss,NC',
#   'SAMPLEID': 1254},
#  44: {'AGE': 31.0,
#   'BBTYPE': 'i',
#   'ETHNICITY': 'Caucasian',
#   'GENDER': 'f',
#   'LOCATION': 'Smithfield,NC',
#   'SAMPLEID': 1258},
#  45: {'AGE': 33.0,
#   'BBTYPE': nan,
#   'ETHNICITY': 'Caucasian',
#   'GENDER': 'm',
#   'LOCATION': 'Smithfield,NC',
#   'SAMPLEID': 1259},
#  46: {'AGE': 10.0,
#   'BBTYPE': nan,
#   'ETHNICITY': 'Caucasian',
#   'GENDER': 'm',
#   'LOCATION': 'Smithfield,NC',
#   'SAMPLEID': 1260},
#  47: {'AGE': 46.0,
#   'BBTYPE': 'i',
#   'ETHNICITY': 'Caucasian',
#   'GENDER': 'm',
#   'LOCATION': 'Raleigh,NC',
#   'SAMPLEID': 1264},
#  48: {'AGE': 10.0,
#   'BBTYPE': 'i',
#   'ETHNICITY': 'Caucasian',
#   'GENDER': 'f',
#   'LOCATION': 'Raleigh,NC',
#   'SAMPLEID': 1265},
#  49: {'AGE': 60.0,
#   'BBTYPE': 'I',
#   'ETHNICITY': 'Caucasian',
#   'GENDER': 'M',
#   'LOCATION': nan,
#   'SAMPLEID': 1273},
#  50: {'AGE': 18.0,
#   'BBTYPE': 'I',
#   'ETHNICITY': 'Caucasian',
#   'GENDER': 'F',
#   'LOCATION': nan,
#   'SAMPLEID': 1275},
#  51: {'AGE': 34.0,
#   'BBTYPE': 'O',
#   'ETHNICITY': 'Caucasian',
#   'GENDER': 'M',
#   'LOCATION': nan,
#   'SAMPLEID': 1276},
#  52: {'AGE': 67.0,
#   'BBTYPE': 'I',
#   'ETHNICITY': 'Caucasian',
#   'GENDER': 'F',
#   'LOCATION': nan,
#   'SAMPLEID': 1277},
#  53: {'AGE': 44.0,
#   'BBTYPE': 'I',
#   'ETHNICITY': nan,
#   'GENDER': 'M',
#   'LOCATION': nan,
#   'SAMPLEID': 1278},
#  54: {'AGE': 60.0,
#   'BBTYPE': 'O',
#   'ETHNICITY': 'Black',
#   'GENDER': 'F',
#   'LOCATION': nan,
#   'SAMPLEID': 1279},
#  55: {'AGE': 30.0,
#   'BBTYPE': 'I',
#   'ETHNICITY': 'PacificIslander',
#   'GENDER': 'F',
#   'LOCATION': nan,
#   'SAMPLEID': 1280},
#  56: {'AGE': 55.0,
#   'BBTYPE': 'I',
#   'ETHNICITY': 'Caucasian',
#   'GENDER': 'F',
#   'LOCATION': nan,
#   'SAMPLEID': 1281},
#  57: {'AGE': 53.0,
#   'BBTYPE': 'I',
#   'ETHNICITY': 'Caucasian',
#   'GENDER': 'F',
#   'LOCATION': nan,
#   'SAMPLEID': 1282},
#  58: {'AGE': 48.0,
#   'BBTYPE': 'I',
#   'ETHNICITY': 'Caucasian',
#   'GENDER': 'M',
#   'LOCATION': nan,
#   'SAMPLEID': 1283},
#  59: {'AGE': 30.0,
#   'BBTYPE': 'I',
#   'ETHNICITY': 'Caucasian',
#   'GENDER': 'F',
#   'LOCATION': nan,
#   'SAMPLEID': 1284},
#  60: {'AGE': 42.0,
#   'BBTYPE': 'Both',
#   'ETHNICITY': 'Caucasian',
#   'GENDER': 'M',
#   'LOCATION': nan,
#   'SAMPLEID': 1285},
#  61: {'AGE': 38.0,
#   'BBTYPE': 'I',
#   'ETHNICITY': 'Caucasian',
#   'GENDER': 'M',
#   'LOCATION': nan,
#   'SAMPLEID': 1286},
#  62: {'AGE': 46.0,
#   'BBTYPE': 'I',
#   'ETHNICITY': 'Caucasian',
#   'GENDER': 'M',
#   'LOCATION': nan,
#   'SAMPLEID': 1287},
#  63: {'AGE': 52.0,
#   'BBTYPE': 'I',
#   'ETHNICITY': 'Caucasian',
#   'GENDER': 'F',
#   'LOCATION': nan,
#   'SAMPLEID': 1288},
#  64: {'AGE': 38.0,
#   'BBTYPE': 'I',
#   'ETHNICITY': 'Black',
#   'GENDER': 'F',
#   'LOCATION': nan,
#   'SAMPLEID': 1289},
#  65: {'AGE': 53.0,
#   'BBTYPE': 'I',
#   'ETHNICITY': 'Caucasian',
#   'GENDER': 'F',
#   'LOCATION': nan,
#   'SAMPLEID': 1290},
#  66: {'AGE': 49.0,
#   'BBTYPE': 'I',
#   'ETHNICITY': 'Caucasian',
#   'GENDER': 'F',
#   'LOCATION': nan,
#   'SAMPLEID': 1291},
#  67: {'AGE': 46.0,
#   'BBTYPE': 'I',
#   'ETHNICITY': 'Caucasian',
#   'GENDER': 'M',
#   'LOCATION': nan,
#   'SAMPLEID': 1292},
#  68: {'AGE': 68.0,
#   'BBTYPE': 'I',
#   'ETHNICITY': 'Caucasian',
#   'GENDER': 'F',
#   'LOCATION': nan,
#   'SAMPLEID': 1293},
#  69: {'AGE': 46.0,
#   'BBTYPE': 'I',
#   'ETHNICITY': 'Caucasian',
#   'GENDER': 'F',
#   'LOCATION': nan,
#   'SAMPLEID': 1294},
#  70: {'AGE': 48.0,
#   'BBTYPE': 'Both',
#   'ETHNICITY': 'Caucasian',
#   'GENDER': 'F',
#   'LOCATION': nan,
#   'SAMPLEID': 1295},
#  71: {'AGE': 10.0,
#   'BBTYPE': 'i',
#   'ETHNICITY': 'Black',
#   'GENDER': 'f',
#   'LOCATION': 'Pinehurst,NC',
#   'SAMPLEID': 1296},
#  72: {'AGE': 10.0,
#   'BBTYPE': nan,
#   'ETHNICITY': 'Caucasion',
#   'GENDER': 'f',
#   'LOCATION': 'Pinehurst,NC',
#   'SAMPLEID': 1297},
#  73: {'AGE': 12.0,
#   'BBTYPE': 'i',
#   'ETHNICITY': 'White',
#   'GENDER': 'm',
#   'LOCATION': 'Pinehurst,NC',
#   'SAMPLEID': 1298},
#  74: {'AGE': 40.0,
#   'BBTYPE': nan,
#   'ETHNICITY': 'Black',
#   'GENDER': 'f',
#   'LOCATION': 'Durham,NC',
#   'SAMPLEID': 1308},
#  75: {'AGE': 6.0,
#   'BBTYPE': nan,
#   'ETHNICITY': 'Black',
#   'GENDER': 'f',
#   'LOCATION': 'Durham,NC',
#   'SAMPLEID': 1309},
#  76: {'AGE': 3.0,
#   'BBTYPE': nan,
#   'ETHNICITY': 'Black',
#   'GENDER': 'm',
#   'LOCATION': 'Durham,NC',
#   'SAMPLEID': 1310},
#  77: {'AGE': 55.0,
#   'BBTYPE': 'o',
#   'ETHNICITY': 'Caucasian',
#   'GENDER': 'F',
#   'LOCATION': 'Cary,NC',
#   'SAMPLEID': 1374},
#  78: {'AGE': nan,
#   'BBTYPE': 'Unknown',
#   'ETHNICITY': nan,
#   'GENDER': nan,
#   'LOCATION': nan,
#   'SAMPLEID': 1415},
#  79: {'AGE': nan,
#   'BBTYPE': nan,
#   'ETHNICITY': 'Caucasian',
#   'GENDER': 'F',
#   'LOCATION': 'Sarasota,FL',
#   'SAMPLEID': 1439},
#  80: {'AGE': 36.0,
#   'BBTYPE': 'I',
#   'ETHNICITY': 'Caucasian',
#   'GENDER': 'F',
#   'LOCATION': 'Raleigh,NC',
#   'SAMPLEID': 1441},
#  81: {'AGE': 57.0,
#   'BBTYPE': 'I',
#   'ETHNICITY': 'Caucasian',
#   'GENDER': 'F',
#   'LOCATION': 'Raleigh,NC',
#   'SAMPLEID': 1443},
#  82: {'AGE': 33.0,
#   'BBTYPE': 'I',
#   'ETHNICITY': 'Caucasian',
#   'GENDER': 'F',
#   'LOCATION': 'Shrewsbury,UK',
#   'SAMPLEID': 1486},
#  83: {'AGE': 30.0,
#   'BBTYPE': 'I',
#   'ETHNICITY': 'Caucasian',
#   'GENDER': 'M',
#   'LOCATION': 'Shrewsbury,UK',
#   'SAMPLEID': 1487},
#  84: {'AGE': 28.0,
#   'BBTYPE': 'I',
#   'ETHNICITY': 'Caucasian',
#   'GENDER': 'F',
#   'LOCATION': 'WashingtonDC',
#   'SAMPLEID': 1489},
#  85: {'AGE': 27.0,
#   'BBTYPE': 'I',
#   'ETHNICITY': 'Caucasian',
#   'GENDER': 'F',
#   'LOCATION': 'DurhamNC',
#   'SAMPLEID': 1490},
#  86: {'AGE': 24.0,
#   'BBTYPE': 'I',
#   'ETHNICITY': 'Caucasian',
#   'GENDER': 'F',
#   'LOCATION': 'WashingtonDC',
#   'SAMPLEID': 1491},
#  87: {'AGE': 35.0,
#   'BBTYPE': 'I',
#   'ETHNICITY': 'Caucasian',
#   'GENDER': 'M',
#   'LOCATION': 'Boone,NC',
#   'SAMPLEID': 1494},
#  88: {'AGE': 57.0,
#   'BBTYPE': 'I',
#   'ETHNICITY': 'Caucasian',
#   'GENDER': 'F',
#   'LOCATION': 'Raleigh,NC',
#   'SAMPLEID': 1495},
#  89: {'AGE': 35.0,
#   'BBTYPE': 'I',
#   'ETHNICITY': 'Caucasian',
#   'GENDER': 'M',
#   'LOCATION': 'Raleigh,NC',
#   'SAMPLEID': 1497},
#  90: {'AGE': 33.0,
#   'BBTYPE': 'I',
#   'ETHNICITY': 'Caucasian',
#   'GENDER': 'M',
#   'LOCATION': 'Waynesville,NC',
#   'SAMPLEID': 1499},
#  91: {'AGE': 32.0,
#   'BBTYPE': 'I',
#   'ETHNICITY': 'Caucasian',
#   'GENDER': 'M',
#   'LOCATION': 'Raleigh,NC',
#   'SAMPLEID': 1500},
#  92: {'AGE': 38.0,
#   'BBTYPE': 'I',
#   'ETHNICITY': nan,
#   'GENDER': 'M',
#   'LOCATION': 'FallsChurch,VA',
#   'SAMPLEID': 1501},
#  93: {'AGE': 27.0,
#   'BBTYPE': 'I',
#   'ETHNICITY': 'Caucasian',
#   'GENDER': 'F',
#   'LOCATION': 'Boone,NC',
#   'SAMPLEID': 1502},
#  94: {'AGE': 32.0,
#   'BBTYPE': 'I',
#   'ETHNICITY': 'Caucasian',
#   'GENDER': 'F',
#   'LOCATION': 'Raleigh,NC',
#   'SAMPLEID': 1503},
#  95: {'AGE': 27.0,
#   'BBTYPE': 'I',
#   'ETHNICITY': 'Caucasian',
#   'GENDER': 'F',
#   'LOCATION': 'Raleigh,NC',
#   'SAMPLEID': 1504},
#  96: {'AGE': 26.0,
#   'BBTYPE': 'I',
#   'ETHNICITY': 'Caucasian',
#   'GENDER': 'F',
#   'LOCATION': 'Durham,NC',
#   'SAMPLEID': 1505},
#  97: {'AGE': 21.0,
#   'BBTYPE': 'I',
#   'ETHNICITY': 'Caucasian',
#   'GENDER': 'F',
#   'LOCATION': 'Raleigh,NC',
#   'SAMPLEID': 1506},
#  98: {'AGE': 46.0,
#   'BBTYPE': 'I',
#   'ETHNICITY': 'Caucasian',
#   'GENDER': 'F',
#   'LOCATION': 'NC',
#   'SAMPLEID': 1507},
#  99: {'AGE': 60.0,
#   'BBTYPE': 'I',
#   'ETHNICITY': 'Caucasian',
#   'GENDER': 'M',
#   'LOCATION': 'NC',
#   'SAMPLEID': 1508},
#  100: {'AGE': 21.0,
#   'BBTYPE': 'I',
#   'ETHNICITY': 'Black',
#   'GENDER': 'F',
#   'LOCATION': 'NC',
#   'SAMPLEID': 1510},
#  101: {'AGE': 46.0,
#   'BBTYPE': 'I',
#   'ETHNICITY': 'Caucasian',
#   'GENDER': 'F',
#   'LOCATION': 'NC',
#   'SAMPLEID': 1511},
#  102: {'AGE': 55.0,
#   'BBTYPE': 'I',
#   'ETHNICITY': 'Caucasian',
#   'GENDER': 'M',
#   'LOCATION': 'NC',
#   'SAMPLEID': 1512},
#  103: {'AGE': 15.0,
#   'BBTYPE': 'I',
#   'ETHNICITY': 'Caucasian',
#   'GENDER': 'M',
#   'LOCATION': 'NC',
#   'SAMPLEID': 1513},
#  104: {'AGE': 3.0,
#   'BBTYPE': 'o',
#   'ETHNICITY': 'Caucasian',
#   'GENDER': 'F',
#   'LOCATION': 'NC',
#   'SAMPLEID': 1514},
#  105: {'AGE': 51.0,
#   'BBTYPE': 'I',
#   'ETHNICITY': 'Caucasian',
#   'GENDER': 'F',
#   'LOCATION': 'NC',
#   'SAMPLEID': 1515},
#  106: {'AGE': 57.0,
#   'BBTYPE': 'I',
#   'ETHNICITY': 'Caucasian',
#   'GENDER': 'M',
#   'LOCATION': 'NC',
#   'SAMPLEID': 1516},
#  107: {'AGE': 27.0,
#   'BBTYPE': 'I',
#   'ETHNICITY': 'Caucasian',
#   'GENDER': 'M',
#   'LOCATION': 'NC',
#   'SAMPLEID': 1517},
#  108: {'AGE': 25.0,
#   'BBTYPE': 'I',
#   'ETHNICITY': 'Caucasian',
#   'GENDER': 'F',
#   'LOCATION': 'GA',
#   'SAMPLEID': 1518},
#  109: {'AGE': 25.0,
#   'BBTYPE': 'I',
#   'ETHNICITY': 'Caucasian',
#   'GENDER': 'F',
#   'LOCATION': 'NC',
#   'SAMPLEID': 1519},
#  110: {'AGE': 10.0,
#   'BBTYPE': 'I',
#   'ETHNICITY': 'Caucasian',
#   'GENDER': 'F',
#   'LOCATION': 'NC',
#   'SAMPLEID': 1521},
#  111: {'AGE': 14.0,
#   'BBTYPE': 'I',
#   'ETHNICITY': 'Caucasian',
#   'GENDER': 'M',
#   'LOCATION': 'NC',
#   'SAMPLEID': 1524},
#  112: {'AGE': 6.0,
#   'BBTYPE': 'I',
#   'ETHNICITY': 'Caucasian',
#   'GENDER': 'M',
#   'LOCATION': 'NC',
#   'SAMPLEID': 1526},
#  113: {'AGE': 34.0,
#   'BBTYPE': 'I',
#   'ETHNICITY': 'Caucasian',
#   'GENDER': 'F',
#   'LOCATION': 'NC',
#   'SAMPLEID': 1527},
#  114: {'AGE': 54.0,
#   'BBTYPE': 'I',
#   'ETHNICITY': 'Caucasian',
#   'GENDER': 'F',
#   'LOCATION': 'NC',
#   'SAMPLEID': 1530},
#  115: {'AGE': 39.0,
#   'BBTYPE': 'I',
#   'ETHNICITY': 'Caucasian',
#   'GENDER': 'M',
#   'LOCATION': 'NC',
#   'SAMPLEID': 1531},
#  116: {'AGE': 38.0,
#   'BBTYPE': 'I',
#   'ETHNICITY': 'Caucasian',
#   'GENDER': 'F',
#   'LOCATION': 'NC',
#   'SAMPLEID': 1532},
#  117: {'AGE': 37.0,
#   'BBTYPE': 'o',
#   'ETHNICITY': 'Black',
#   'GENDER': 'M',
#   'LOCATION': 'NC',
#   'SAMPLEID': 1533},
#  118: {'AGE': 42.0,
#   'BBTYPE': 'I',
#   'ETHNICITY': 'Caucasian',
#   'GENDER': 'F',
#   'LOCATION': 'NC',
#   'SAMPLEID': 1534},
#  119: {'AGE': 35.0,
#   'BBTYPE': 'I',
#   'ETHNICITY': 'Caucasian',
#   'GENDER': 'M',
#   'LOCATION': 'NC',
#   'SAMPLEID': 1535},
#  120: {'AGE': 26.0,
#   'BBTYPE': 'I',
#   'ETHNICITY': 'Caucasian',
#   'GENDER': 'F',
#   'LOCATION': 'NC',
#   'SAMPLEID': 1536},
#  121: {'AGE': 28.0,
#   'BBTYPE': 'I',
#   'ETHNICITY': 'Caucasian',
#   'GENDER': 'M',
#   'LOCATION': 'NC',
#   'SAMPLEID': 1537},
#  122: {'AGE': 39.0,
#   'BBTYPE': 'I',
#   'ETHNICITY': 'Caucasian',
#   'GENDER': 'F',
#   'LOCATION': 'NC',
#   'SAMPLEID': 1539},
#  123: {'AGE': 30.0,
#   'BBTYPE': 'I',
#   'ETHNICITY': 'Caucasian',
#   'GENDER': 'M',
#   'LOCATION': 'NC',
#   'SAMPLEID': 1540},
#  124: {'AGE': 26.0,
#   'BBTYPE': 'I',
#   'ETHNICITY': 'Caucasian',
#   'GENDER': 'F',
#   'LOCATION': 'NC',
#   'SAMPLEID': 1541},
#  125: {'AGE': 36.0,
#   'BBTYPE': 'I',
#   'ETHNICITY': 'Caucasian',
#   'GENDER': 'M',
#   'LOCATION': 'NC',
#   'SAMPLEID': 1542},
#  126: {'AGE': 34.0,
#   'BBTYPE': 'I',
#   'ETHNICITY': 'Caucasian',
#   'GENDER': 'F',
#   'LOCATION': 'NC',
#   'SAMPLEID': 1543},
#  127: {'AGE': 33.0,
#   'BBTYPE': 'I',
#   'ETHNICITY': 'Caucasian',
#   'GENDER': 'F',
#   'LOCATION': 'NC',
#   'SAMPLEID': 1544},
#  128: {'AGE': 39.0,
#   'BBTYPE': 'I',
#   'ETHNICITY': 'Caucasian',
#   'GENDER': 'F',
#   'LOCATION': 'NC',
#   'SAMPLEID': 1545},
#  129: {'AGE': 34.0,
#   'BBTYPE': 'I',
#   'ETHNICITY': 'Caucasian',
#   'GENDER': 'M',
#   'LOCATION': 'NC',
#   'SAMPLEID': 1546},
#  130: {'AGE': 38.0,
#   'BBTYPE': 'I',
#   'ETHNICITY': nan,
#   'GENDER': 'M',
#   'LOCATION': 'NC',
#   'SAMPLEID': 1547},
#  131: {'AGE': 6.0,
#   'BBTYPE': 'I',
#   'ETHNICITY': 'Caucasian',
#   'GENDER': 'M',
#   'LOCATION': 'NC',
#   'SAMPLEID': 1548},
#  132: {'AGE': 37.0,
#   'BBTYPE': 'I',
#   'ETHNICITY': 'Caucasian',
#   'GENDER': 'F',
#   'LOCATION': 'NC',
#   'SAMPLEID': 1549},
#  133: {'AGE': 29.0,
#   'BBTYPE': 'I',
#   'ETHNICITY': 'Caucasian',
#   'GENDER': 'F',
#   'LOCATION': 'NC',
#   'SAMPLEID': 1550},
#  134: {'AGE': 26.0,
#   'BBTYPE': 'I',
#   'ETHNICITY': 'Caucasian',
#   'GENDER': 'M',
#   'LOCATION': 'NC',
#   'SAMPLEID': 1551},
#  135: {'AGE': 25.0,
#   'BBTYPE': 'I',
#   'ETHNICITY': 'Caucasian',
#   'GENDER': 'M',
#   'LOCATION': 'NC',
#   'SAMPLEID': 1552},
#  136: {'AGE': 50.0,
#   'BBTYPE': 'I',
#   'ETHNICITY': 'Caucasian',
#   'GENDER': 'F',
#   'LOCATION': 'NC',
#   'SAMPLEID': 1553},
#  137: {'AGE': 18.0,
#   'BBTYPE': 'I',
#   'ETHNICITY': 'Caucasian',
#   'GENDER': 'F',
#   'LOCATION': 'NC',
#   'SAMPLEID': 1554},
#  138: {'AGE': 26.0,
#   'BBTYPE': 'I',
#   'ETHNICITY': 'Caucasian',
#   'GENDER': 'M',
#   'LOCATION': 'NC',
#   'SAMPLEID': 1555},
#  139: {'AGE': 34.0,
#   'BBTYPE': 'I',
#   'ETHNICITY': 'Hispanic',
#   'GENDER': 'M',
#   'LOCATION': 'NC',
#   'SAMPLEID': 1556},
#  140: {'AGE': 26.0,
#   'BBTYPE': 'I',
#   'ETHNICITY': 'Caucasian',
#   'GENDER': 'F',
#   'LOCATION': 'NC',
#   'SAMPLEID': 1557},
#  141: {'AGE': 26.0,
#   'BBTYPE': 'I',
#   'ETHNICITY': 'Caucasian',
#   'GENDER': 'M',
#   'LOCATION': 'NC',
#   'SAMPLEID': 1558},
#  142: {'AGE': 31.0,
#   'BBTYPE': 'I',
#   'ETHNICITY': 'Caucasian',
#   'GENDER': 'M',
#   'LOCATION': 'NC',
#   'SAMPLEID': 1561},
#  143: {'AGE': 39.0,
#   'BBTYPE': 'I',
#   'ETHNICITY': 'Caucasian',
#   'GENDER': 'M',
#   'LOCATION': 'MT',
#   'SAMPLEID': 1562},
#  144: {'AGE': 31.0,
#   'BBTYPE': 'I',
#   'ETHNICITY': 'Caucasian',
#   'GENDER': 'F',
#   'LOCATION': 'MT',
#   'SAMPLEID': 1563},
#  145: {'AGE': 36.0,
#   'BBTYPE': 'I',
#   'ETHNICITY': 'Caucasian',
#   'GENDER': 'F',
#   'LOCATION': 'NC',
#   'SAMPLEID': 1564},
#  146: {'AGE': 33.0,
#   'BBTYPE': 'I',
#   'ETHNICITY': 'Caucasian',
#   'GENDER': 'F',
#   'LOCATION': 'NC',
#   'SAMPLEID': 1572},
#  147: {'AGE': 53.0,
#   'BBTYPE': 'I',
#   'ETHNICITY': 'Caucasian',
#   'GENDER': 'M',
#   'LOCATION': 'NC',
#   'SAMPLEID': 1573},
#  148: {'AGE': 30.0,
#   'BBTYPE': 'I',
#   'ETHNICITY': 'Caucasian',
#   'GENDER': 'M',
#   'LOCATION': 'OK',
#   'SAMPLEID': 1574},
#  149: {'AGE': 33.0,
#   'BBTYPE': 'I',
#   'ETHNICITY': 'Caucasian',
#   'GENDER': 'F',
#   'LOCATION': 'NC',
#   'SAMPLEID': 1576},
#  150: {'AGE': 26.0,
#   'BBTYPE': 'I',
#   'ETHNICITY': 'Caucasian',
#   'GENDER': 'M',
#   'LOCATION': 'NC',
#   'SAMPLEID': 1577},
#  151: {'AGE': 22.0,
#   'BBTYPE': 'I',
#   'ETHNICITY': 'Asian(American)',
#   'GENDER': 'F',
#   'LOCATION': 'NC',
#   'SAMPLEID': 1581},
#  152: {'AGE': 22.0,
#   'BBTYPE': 'I',
#   'ETHNICITY': 'Caucasian',
#   'GENDER': 'F',
#   'LOCATION': 'NC',
#   'SAMPLEID': 1601}}

# %%
bbb_meta_list = []

# %%
bbb_meta_list.append(bbb_meta_dict)

# %%
bbb_meta_list
# Out:
# [{0: {'AGE': 24.0,
#    'BBTYPE': 'I',
#    'ETHNICITY': 'Caucasian',
#    'GENDER': 'F',
#    'LOCATION': 'Beaufort/NC',
#    'SAMPLEID': 940},
#   1: {'AGE': 34.0,
#    'BBTYPE': 'I',
#    'ETHNICITY': 'Caucasian/Midleastern',
#    'GENDER': 'F',
#    'LOCATION': 'Chicago/IL',
#    'SAMPLEID': 941},
#   2: {'AGE': 49.0,
#    'BBTYPE': 'I',
#    'ETHNICITY': 'Caucasian',
#    'GENDER': 'F',
#    'LOCATION': 'Omaha/NE',
#    'SAMPLEID': 943},
#   3: {'AGE': 44.0,
#    'BBTYPE': 'I',
#    'ETHNICITY': 'European',
#    'GENDER': 'M',
#    'LOCATION': 'NewHaven/CT',
#    'SAMPLEID': 944},
#   4: {'AGE': 48.0,
#    'BBTYPE': 'I',
#    'ETHNICITY': 'Caucasian',
#    'GENDER': 'F',
#    'LOCATION': 'Philidelphia/PA',
#    'SAMPLEID': 945},
#   5: {'AGE': 42.0,
#    'BBTYPE': 'I',
#    'ETHNICITY': 'Caucasian',
#    'GENDER': 'F',
#    'LOCATION': 'Deerfield/MA',
#    'SAMPLEID': 946},
#   6: {'AGE': 49.0,
#    'BBTYPE': 'I',
#    'ETHNICITY': 'Caucasian',
#    'GENDER': 'M',
#    'LOCATION': 'ChapelHill/NC',
#    'SAMPLEID': 947},
#   7: {'AGE': 20.0,
#    'BBTYPE': 'I',
#    'ETHNICITY': 'Caucasian',
#    'GENDER': 'M',
#    'LOCATION': 'ChapelHill/NC',
#    'SAMPLEID': 948},
#   8: {'AGE': 51.0,
#    'BBTYPE': 'I',
#    'ETHNICITY': 'Caucasian',
#    'GENDER': 'F',
#    'LOCATION': 'Durham/NC',
#    'SAMPLEID': 949},
#   9: {'AGE': 51.0,
#    'BBTYPE': 'I',
#    'ETHNICITY': 'Caucasian',
#    'GENDER': 'M',
#    'LOCATION': 'NewYork/NY',
#    'SAMPLEID': 950},
#   10: {'AGE': 51.0,
#    'BBTYPE': 'I',
#    'ETHNICITY': 'Caucasian',
#    'GENDER': 'F',
#    'LOCATION': 'Seattle/WA',
#    'SAMPLEID': 952},
#   11: {'AGE': 38.0,
#    'BBTYPE': 'I',
#    'ETHNICITY': 'Caucasian',
#    'GENDER': 'F',
#    'LOCATION': 'Chicago/IL',
#    'SAMPLEID': 953},
#   12: {'AGE': 26.0,
#    'BBTYPE': 'I',
#    'ETHNICITY': 'Caucasian',
#    'GENDER': 'M',
#    'LOCATION': 'NewYork/NY',
#    'SAMPLEID': 954},
#   13: {'AGE': 27.0,
#    'BBTYPE': 'I',
#    'ETHNICITY': 'Caucasian',
#    'GENDER': 'F',
#    'LOCATION': 'NewYork/NY',
#    'SAMPLEID': 955},
#   14: {'AGE': 16.0,
#    'BBTYPE': 'I',
#    'ETHNICITY': 'Caucasian',
#    'GENDER': 'M',
#    'LOCATION': 'Jacksonville/NC',
#    'SAMPLEID': 956},
#   15: {'AGE': 43.0,
#    'BBTYPE': 'I',
#    'ETHNICITY': 'Caucasian',
#    'GENDER': 'M',
#    'LOCATION': 'Wilmington/NC',
#    'SAMPLEID': 958},
#   16: {'AGE': 40.0,
#    'BBTYPE': 'I',
#    'ETHNICITY': 'Caucasian',
#    'GENDER': 'M',
#    'LOCATION': 'Carrboro/NC',
#    'SAMPLEID': 959},
#   17: {'AGE': 48.0,
#    'BBTYPE': 'I',
#    'ETHNICITY': 'Caucasian',
#    'GENDER': 'M',
#    'LOCATION': 'Lexington/NC',
#    'SAMPLEID': 960},
#   18: {'AGE': 35.0,
#    'BBTYPE': 'i',
#    'ETHNICITY': 'Caucasian',
#    'GENDER': 'F',
#    'LOCATION': 'Edmonton,AB',
#    'SAMPLEID': 961},
#   19: {'AGE': 56.0,
#    'BBTYPE': 'i',
#    'ETHNICITY': 'Caucasian',
#    'GENDER': 'F',
#    'LOCATION': 'Washington,DC',
#    'SAMPLEID': 962},
#   20: {'AGE': 33.0,
#    'BBTYPE': 'I',
#    'ETHNICITY': 'Caucasian',
#    'GENDER': 'F',
#    'LOCATION': 'Ithaca/NY',
#    'SAMPLEID': 963},
#   21: {'AGE': 43.0,
#    'BBTYPE': 'I',
#    'ETHNICITY': 'Caucasian',
#    'GENDER': 'F',
#    'LOCATION': 'UK/London',
#    'SAMPLEID': 964},
#   22: {'AGE': 56.0,
#    'BBTYPE': 'I',
#    'ETHNICITY': 'Caucasian',
#    'GENDER': 'M',
#    'LOCATION': 'Needham/MA',
#    'SAMPLEID': 966},
#   23: {'AGE': 43.0,
#    'BBTYPE': 'I',
#    'ETHNICITY': 'Caucasian/Jewish',
#    'GENDER': 'F',
#    'LOCATION': 'ChapelHill/NC',
#    'SAMPLEID': 967},
#   24: {'AGE': 38.0,
#    'BBTYPE': 'I',
#    'ETHNICITY': 'Caucasian',
#    'GENDER': 'F',
#    'LOCATION': 'St.Louis/MI',
#    'SAMPLEID': 968},
#   25: {'AGE': 31.0,
#    'BBTYPE': 'I',
#    'ETHNICITY': 'Caucasian/Asian',
#    'GENDER': 'F',
#    'LOCATION': 'ChevyChase/MD',
#    'SAMPLEID': 969},
#   26: {'AGE': 42.0,
#    'BBTYPE': 'i',
#    'ETHNICITY': 'Caucasian',
#    'GENDER': 'F',
#    'LOCATION': 'SanDiego/CA',
#    'SAMPLEID': 970},
#   27: {'AGE': 36.0,
#    'BBTYPE': 'I',
#    'ETHNICITY': 'Asian(South)',
#    'GENDER': 'M',
#    'LOCATION': 'SantaBarbara/CA',
#    'SAMPLEID': 971},
#   28: {'AGE': 31.0,
#    'BBTYPE': 'I',
#    'ETHNICITY': 'Caucasian',
#    'GENDER': 'F',
#    'LOCATION': 'Charlotte/NC',
#    'SAMPLEID': 972},
#   29: {'AGE': 4.0,
#    'BBTYPE': 'I',
#    'ETHNICITY': 'Caucasian',
#    'GENDER': 'F',
#    'LOCATION': 'Charlotte/NC',
#    'SAMPLEID': 973},
#   30: {'AGE': 57.0,
#    'BBTYPE': 'I',
#    'ETHNICITY': 'Caucasian',
#    'GENDER': 'F',
#    'LOCATION': 'Raleigh/NC',
#    'SAMPLEID': 974},
#   31: {'AGE': 60.0,
#    'BBTYPE': 'I',
#    'ETHNICITY': 'Caucasian',
#    'GENDER': 'F',
#    'LOCATION': 'NewCanaan/CT',
#    'SAMPLEID': 975},
#   32: {'AGE': 21.0,
#    'BBTYPE': nan,
#    'ETHNICITY': 'Hispanic',
#    'GENDER': 'F',
#    'LOCATION': 'Durham/NC',
#    'SAMPLEID': 978},
#   33: {'AGE': 34.0,
#    'BBTYPE': 'I',
#    'ETHNICITY': 'Caucasian',
#    'GENDER': 'M',
#    'LOCATION': nan,
#    'SAMPLEID': 1233},
#   34: {'AGE': nan,
#    'BBTYPE': 'I',
#    'ETHNICITY': 'Caucasian',
#    'GENDER': 'F',
#    'LOCATION': nan,
#    'SAMPLEID': 1234},
#   35: {'AGE': 43.0,
#    'BBTYPE': nan,
#    'ETHNICITY': 'Caucasian',
#    'GENDER': 'F',
#    'LOCATION': nan,
#    'SAMPLEID': 1235},
#   36: {'AGE': 54.0,
#    'BBTYPE': nan,
#    'ETHNICITY': 'Caucasian',
#    'GENDER': 'F',
#    'LOCATION': nan,
#    'SAMPLEID': 1236},
#   37: {'AGE': 9.0,
#    'BBTYPE': 'i',
#    'ETHNICITY': 'Caucasian',
#    'GENDER': 'F',
#    'LOCATION': 'ChapelHill,NC',
#    'SAMPLEID': 1237},
#   38: {'AGE': 41.0,
#    'BBTYPE': 'i',
#    'ETHNICITY': 'Caucasian',
#    'GENDER': 'F',
#    'LOCATION': 'Raleigh,NC',
#    'SAMPLEID': 1238},
#   39: {'AGE': 44.0,
#    'BBTYPE': 'i',
#    'ETHNICITY': 'Caucasian',
#    'GENDER': 'F',
#    'LOCATION': 'Raleigh,NC',
#    'SAMPLEID': 1242},
#   40: {'AGE': 49.0,
#    'BBTYPE': 'i',
#    'ETHNICITY': 'Caucasian',
#    'GENDER': 'M',
#    'LOCATION': 'Raleigh,NC',
#    'SAMPLEID': 1243},
#   41: {'AGE': 2.0,
#    'BBTYPE': nan,
#    'ETHNICITY': 'Caucasian',
#    'GENDER': 'F',
#    'LOCATION': 'Atlanta,GA',
#    'SAMPLEID': 1246},
#   42: {'AGE': 24.0,
#    'BBTYPE': 'i',
#    'ETHNICITY': 'Caucasian',
#    'GENDER': 'M',
#    'LOCATION': 'Voss,NC',
#    'SAMPLEID': 1253},
#   43: {'AGE': 1.0,
#    'BBTYPE': 'o',
#    'ETHNICITY': 'Caucasian',
#    'GENDER': 'F',
#    'LOCATION': 'Voss,NC',
#    'SAMPLEID': 1254},
#   44: {'AGE': 31.0,
#    'BBTYPE': 'i',
#    'ETHNICITY': 'Caucasian',
#    'GENDER': 'f',
#    'LOCATION': 'Smithfield,NC',
#    'SAMPLEID': 1258},
#   45: {'AGE': 33.0,
#    'BBTYPE': nan,
#    'ETHNICITY': 'Caucasian',
#    'GENDER': 'm',
#    'LOCATION': 'Smithfield,NC',
#    'SAMPLEID': 1259},
#   46: {'AGE': 10.0,
#    'BBTYPE': nan,
#    'ETHNICITY': 'Caucasian',
#    'GENDER': 'm',
#    'LOCATION': 'Smithfield,NC',
#    'SAMPLEID': 1260},
#   47: {'AGE': 46.0,
#    'BBTYPE': 'i',
#    'ETHNICITY': 'Caucasian',
#    'GENDER': 'm',
#    'LOCATION': 'Raleigh,NC',
#    'SAMPLEID': 1264},
#   48: {'AGE': 10.0,
#    'BBTYPE': 'i',
#    'ETHNICITY': 'Caucasian',
#    'GENDER': 'f',
#    'LOCATION': 'Raleigh,NC',
#    'SAMPLEID': 1265},
#   49: {'AGE': 60.0,
#    'BBTYPE': 'I',
#    'ETHNICITY': 'Caucasian',
#    'GENDER': 'M',
#    'LOCATION': nan,
#    'SAMPLEID': 1273},
#   50: {'AGE': 18.0,
#    'BBTYPE': 'I',
#    'ETHNICITY': 'Caucasian',
#    'GENDER': 'F',
#    'LOCATION': nan,
#    'SAMPLEID': 1275},
#   51: {'AGE': 34.0,
#    'BBTYPE': 'O',
#    'ETHNICITY': 'Caucasian',
#    'GENDER': 'M',
#    'LOCATION': nan,
#    'SAMPLEID': 1276},
#   52: {'AGE': 67.0,
#    'BBTYPE': 'I',
#    'ETHNICITY': 'Caucasian',
#    'GENDER': 'F',
#    'LOCATION': nan,
#    'SAMPLEID': 1277},
#   53: {'AGE': 44.0,
#    'BBTYPE': 'I',
#    'ETHNICITY': nan,
#    'GENDER': 'M',
#    'LOCATION': nan,
#    'SAMPLEID': 1278},
#   54: {'AGE': 60.0,
#    'BBTYPE': 'O',
#    'ETHNICITY': 'Black',
#    'GENDER': 'F',
#    'LOCATION': nan,
#    'SAMPLEID': 1279},
#   55: {'AGE': 30.0,
#    'BBTYPE': 'I',
#    'ETHNICITY': 'PacificIslander',
#    'GENDER': 'F',
#    'LOCATION': nan,
#    'SAMPLEID': 1280},
#   56: {'AGE': 55.0,
#    'BBTYPE': 'I',
#    'ETHNICITY': 'Caucasian',
#    'GENDER': 'F',
#    'LOCATION': nan,
#    'SAMPLEID': 1281},
#   57: {'AGE': 53.0,
#    'BBTYPE': 'I',
#    'ETHNICITY': 'Caucasian',
#    'GENDER': 'F',
#    'LOCATION': nan,
#    'SAMPLEID': 1282},
#   58: {'AGE': 48.0,
#    'BBTYPE': 'I',
#    'ETHNICITY': 'Caucasian',
#    'GENDER': 'M',
#    'LOCATION': nan,
#    'SAMPLEID': 1283},
#   59: {'AGE': 30.0,
#    'BBTYPE': 'I',
#    'ETHNICITY': 'Caucasian',
#    'GENDER': 'F',
#    'LOCATION': nan,
#    'SAMPLEID': 1284},
#   60: {'AGE': 42.0,
#    'BBTYPE': 'Both',
#    'ETHNICITY': 'Caucasian',
#    'GENDER': 'M',
#    'LOCATION': nan,
#    'SAMPLEID': 1285},
#   61: {'AGE': 38.0,
#    'BBTYPE': 'I',
#    'ETHNICITY': 'Caucasian',
#    'GENDER': 'M',
#    'LOCATION': nan,
#    'SAMPLEID': 1286},
#   62: {'AGE': 46.0,
#    'BBTYPE': 'I',
#    'ETHNICITY': 'Caucasian',
#    'GENDER': 'M',
#    'LOCATION': nan,
#    'SAMPLEID': 1287},
#   63: {'AGE': 52.0,
#    'BBTYPE': 'I',
#    'ETHNICITY': 'Caucasian',
#    'GENDER': 'F',
#    'LOCATION': nan,
#    'SAMPLEID': 1288},
#   64: {'AGE': 38.0,
#    'BBTYPE': 'I',
#    'ETHNICITY': 'Black',
#    'GENDER': 'F',
#    'LOCATION': nan,
#    'SAMPLEID': 1289},
#   65: {'AGE': 53.0,
#    'BBTYPE': 'I',
#    'ETHNICITY': 'Caucasian',
#    'GENDER': 'F',
#    'LOCATION': nan,
#    'SAMPLEID': 1290},
#   66: {'AGE': 49.0,
#    'BBTYPE': 'I',
#    'ETHNICITY': 'Caucasian',
#    'GENDER': 'F',
#    'LOCATION': nan,
#    'SAMPLEID': 1291},
#   67: {'AGE': 46.0,
#    'BBTYPE': 'I',
#    'ETHNICITY': 'Caucasian',
#    'GENDER': 'M',
#    'LOCATION': nan,
#    'SAMPLEID': 1292},
#   68: {'AGE': 68.0,
#    'BBTYPE': 'I',
#    'ETHNICITY': 'Caucasian',
#    'GENDER': 'F',
#    'LOCATION': nan,
#    'SAMPLEID': 1293},
#   69: {'AGE': 46.0,
#    'BBTYPE': 'I',
#    'ETHNICITY': 'Caucasian',
#    'GENDER': 'F',
#    'LOCATION': nan,
#    'SAMPLEID': 1294},
#   70: {'AGE': 48.0,
#    'BBTYPE': 'Both',
#    'ETHNICITY': 'Caucasian',
#    'GENDER': 'F',
#    'LOCATION': nan,
#    'SAMPLEID': 1295},
#   71: {'AGE': 10.0,
#    'BBTYPE': 'i',
#    'ETHNICITY': 'Black',
#    'GENDER': 'f',
#    'LOCATION': 'Pinehurst,NC',
#    'SAMPLEID': 1296},
#   72: {'AGE': 10.0,
#    'BBTYPE': nan,
#    'ETHNICITY': 'Caucasion',
#    'GENDER': 'f',
#    'LOCATION': 'Pinehurst,NC',
#    'SAMPLEID': 1297},
#   73: {'AGE': 12.0,
#    'BBTYPE': 'i',
#    'ETHNICITY': 'White',
#    'GENDER': 'm',
#    'LOCATION': 'Pinehurst,NC',
#    'SAMPLEID': 1298},
#   74: {'AGE': 40.0,
#    'BBTYPE': nan,
#    'ETHNICITY': 'Black',
#    'GENDER': 'f',
#    'LOCATION': 'Durham,NC',
#    'SAMPLEID': 1308},
#   75: {'AGE': 6.0,
#    'BBTYPE': nan,
#    'ETHNICITY': 'Black',
#    'GENDER': 'f',
#    'LOCATION': 'Durham,NC',
#    'SAMPLEID': 1309},
#   76: {'AGE': 3.0,
#    'BBTYPE': nan,
#    'ETHNICITY': 'Black',
#    'GENDER': 'm',
#    'LOCATION': 'Durham,NC',
#    'SAMPLEID': 1310},
#   77: {'AGE': 55.0,
#    'BBTYPE': 'o',
#    'ETHNICITY': 'Caucasian',
#    'GENDER': 'F',
#    'LOCATION': 'Cary,NC',
#    'SAMPLEID': 1374},
#   78: {'AGE': nan,
#    'BBTYPE': 'Unknown',
#    'ETHNICITY': nan,
#    'GENDER': nan,
#    'LOCATION': nan,
#    'SAMPLEID': 1415},
#   79: {'AGE': nan,
#    'BBTYPE': nan,
#    'ETHNICITY': 'Caucasian',
#    'GENDER': 'F',
#    'LOCATION': 'Sarasota,FL',
#    'SAMPLEID': 1439},
#   80: {'AGE': 36.0,
#    'BBTYPE': 'I',
#    'ETHNICITY': 'Caucasian',
#    'GENDER': 'F',
#    'LOCATION': 'Raleigh,NC',
#    'SAMPLEID': 1441},
#   81: {'AGE': 57.0,
#    'BBTYPE': 'I',
#    'ETHNICITY': 'Caucasian',
#    'GENDER': 'F',
#    'LOCATION': 'Raleigh,NC',
#    'SAMPLEID': 1443},
#   82: {'AGE': 33.0,
#    'BBTYPE': 'I',
#    'ETHNICITY': 'Caucasian',
#    'GENDER': 'F',
#    'LOCATION': 'Shrewsbury,UK',
#    'SAMPLEID': 1486},
#   83: {'AGE': 30.0,
#    'BBTYPE': 'I',
#    'ETHNICITY': 'Caucasian',
#    'GENDER': 'M',
#    'LOCATION': 'Shrewsbury,UK',
#    'SAMPLEID': 1487},
#   84: {'AGE': 28.0,
#    'BBTYPE': 'I',
#    'ETHNICITY': 'Caucasian',
#    'GENDER': 'F',
#    'LOCATION': 'WashingtonDC',
#    'SAMPLEID': 1489},
#   85: {'AGE': 27.0,
#    'BBTYPE': 'I',
#    'ETHNICITY': 'Caucasian',
#    'GENDER': 'F',
#    'LOCATION': 'DurhamNC',
#    'SAMPLEID': 1490},
#   86: {'AGE': 24.0,
#    'BBTYPE': 'I',
#    'ETHNICITY': 'Caucasian',
#    'GENDER': 'F',
#    'LOCATION': 'WashingtonDC',
#    'SAMPLEID': 1491},
#   87: {'AGE': 35.0,
#    'BBTYPE': 'I',
#    'ETHNICITY': 'Caucasian',
#    'GENDER': 'M',
#    'LOCATION': 'Boone,NC',
#    'SAMPLEID': 1494},
#   88: {'AGE': 57.0,
#    'BBTYPE': 'I',
#    'ETHNICITY': 'Caucasian',
#    'GENDER': 'F',
#    'LOCATION': 'Raleigh,NC',
#    'SAMPLEID': 1495},
#   89: {'AGE': 35.0,
#    'BBTYPE': 'I',
#    'ETHNICITY': 'Caucasian',
#    'GENDER': 'M',
#    'LOCATION': 'Raleigh,NC',
#    'SAMPLEID': 1497},
#   90: {'AGE': 33.0,
#    'BBTYPE': 'I',
#    'ETHNICITY': 'Caucasian',
#    'GENDER': 'M',
#    'LOCATION': 'Waynesville,NC',
#    'SAMPLEID': 1499},
#   91: {'AGE': 32.0,
#    'BBTYPE': 'I',
#    'ETHNICITY': 'Caucasian',
#    'GENDER': 'M',
#    'LOCATION': 'Raleigh,NC',
#    'SAMPLEID': 1500},
#   92: {'AGE': 38.0,
#    'BBTYPE': 'I',
#    'ETHNICITY': nan,
#    'GENDER': 'M',
#    'LOCATION': 'FallsChurch,VA',
#    'SAMPLEID': 1501},
#   93: {'AGE': 27.0,
#    'BBTYPE': 'I',
#    'ETHNICITY': 'Caucasian',
#    'GENDER': 'F',
#    'LOCATION': 'Boone,NC',
#    'SAMPLEID': 1502},
#   94: {'AGE': 32.0,
#    'BBTYPE': 'I',
#    'ETHNICITY': 'Caucasian',
#    'GENDER': 'F',
#    'LOCATION': 'Raleigh,NC',
#    'SAMPLEID': 1503},
#   95: {'AGE': 27.0,
#    'BBTYPE': 'I',
#    'ETHNICITY': 'Caucasian',
#    'GENDER': 'F',
#    'LOCATION': 'Raleigh,NC',
#    'SAMPLEID': 1504},
#   96: {'AGE': 26.0,
#    'BBTYPE': 'I',
#    'ETHNICITY': 'Caucasian',
#    'GENDER': 'F',
#    'LOCATION': 'Durham,NC',
#    'SAMPLEID': 1505},
#   97: {'AGE': 21.0,
#    'BBTYPE': 'I',
#    'ETHNICITY': 'Caucasian',
#    'GENDER': 'F',
#    'LOCATION': 'Raleigh,NC',
#    'SAMPLEID': 1506},
#   98: {'AGE': 46.0,
#    'BBTYPE': 'I',
#    'ETHNICITY': 'Caucasian',
#    'GENDER': 'F',
#    'LOCATION': 'NC',
#    'SAMPLEID': 1507},
#   99: {'AGE': 60.0,
#    'BBTYPE': 'I',
#    'ETHNICITY': 'Caucasian',
#    'GENDER': 'M',
#    'LOCATION': 'NC',
#    'SAMPLEID': 1508},
#   100: {'AGE': 21.0,
#    'BBTYPE': 'I',
#    'ETHNICITY': 'Black',
#    'GENDER': 'F',
#    'LOCATION': 'NC',
#    'SAMPLEID': 1510},
#   101: {'AGE': 46.0,
#    'BBTYPE': 'I',
#    'ETHNICITY': 'Caucasian',
#    'GENDER': 'F',
#    'LOCATION': 'NC',
#    'SAMPLEID': 1511},
#   102: {'AGE': 55.0,
#    'BBTYPE': 'I',
#    'ETHNICITY': 'Caucasian',
#    'GENDER': 'M',
#    'LOCATION': 'NC',
#    'SAMPLEID': 1512},
#   103: {'AGE': 15.0,
#    'BBTYPE': 'I',
#    'ETHNICITY': 'Caucasian',
#    'GENDER': 'M',
#    'LOCATION': 'NC',
#    'SAMPLEID': 1513},
#   104: {'AGE': 3.0,
#    'BBTYPE': 'o',
#    'ETHNICITY': 'Caucasian',
#    'GENDER': 'F',
#    'LOCATION': 'NC',
#    'SAMPLEID': 1514},
#   105: {'AGE': 51.0,
#    'BBTYPE': 'I',
#    'ETHNICITY': 'Caucasian',
#    'GENDER': 'F',
#    'LOCATION': 'NC',
#    'SAMPLEID': 1515},
#   106: {'AGE': 57.0,
#    'BBTYPE': 'I',
#    'ETHNICITY': 'Caucasian',
#    'GENDER': 'M',
#    'LOCATION': 'NC',
#    'SAMPLEID': 1516},
#   107: {'AGE': 27.0,
#    'BBTYPE': 'I',
#    'ETHNICITY': 'Caucasian',
#    'GENDER': 'M',
#    'LOCATION': 'NC',
#    'SAMPLEID': 1517},
#   108: {'AGE': 25.0,
#    'BBTYPE': 'I',
#    'ETHNICITY': 'Caucasian',
#    'GENDER': 'F',
#    'LOCATION': 'GA',
#    'SAMPLEID': 1518},
#   109: {'AGE': 25.0,
#    'BBTYPE': 'I',
#    'ETHNICITY': 'Caucasian',
#    'GENDER': 'F',
#    'LOCATION': 'NC',
#    'SAMPLEID': 1519},
#   110: {'AGE': 10.0,
#    'BBTYPE': 'I',
#    'ETHNICITY': 'Caucasian',
#    'GENDER': 'F',
#    'LOCATION': 'NC',
#    'SAMPLEID': 1521},
#   111: {'AGE': 14.0,
#    'BBTYPE': 'I',
#    'ETHNICITY': 'Caucasian',
#    'GENDER': 'M',
#    'LOCATION': 'NC',
#    'SAMPLEID': 1524},
#   112: {'AGE': 6.0,
#    'BBTYPE': 'I',
#    'ETHNICITY': 'Caucasian',
#    'GENDER': 'M',
#    'LOCATION': 'NC',
#    'SAMPLEID': 1526},
#   113: {'AGE': 34.0,
#    'BBTYPE': 'I',
#    'ETHNICITY': 'Caucasian',
#    'GENDER': 'F',
#    'LOCATION': 'NC',
#    'SAMPLEID': 1527},
#   114: {'AGE': 54.0,
#    'BBTYPE': 'I',
#    'ETHNICITY': 'Caucasian',
#    'GENDER': 'F',
#    'LOCATION': 'NC',
#    'SAMPLEID': 1530},
#   115: {'AGE': 39.0,
#    'BBTYPE': 'I',
#    'ETHNICITY': 'Caucasian',
#    'GENDER': 'M',
#    'LOCATION': 'NC',
#    'SAMPLEID': 1531},
#   116: {'AGE': 38.0,
#    'BBTYPE': 'I',
#    'ETHNICITY': 'Caucasian',
#    'GENDER': 'F',
#    'LOCATION': 'NC',
#    'SAMPLEID': 1532},
#   117: {'AGE': 37.0,
#    'BBTYPE': 'o',
#    'ETHNICITY': 'Black',
#    'GENDER': 'M',
#    'LOCATION': 'NC',
#    'SAMPLEID': 1533},
#   118: {'AGE': 42.0,
#    'BBTYPE': 'I',
#    'ETHNICITY': 'Caucasian',
#    'GENDER': 'F',
#    'LOCATION': 'NC',
#    'SAMPLEID': 1534},
#   119: {'AGE': 35.0,
#    'BBTYPE': 'I',
#    'ETHNICITY': 'Caucasian',
#    'GENDER': 'M',
#    'LOCATION': 'NC',
#    'SAMPLEID': 1535},
#   120: {'AGE': 26.0,
#    'BBTYPE': 'I',
#    'ETHNICITY': 'Caucasian',
#    'GENDER': 'F',
#    'LOCATION': 'NC',
#    'SAMPLEID': 1536},
#   121: {'AGE': 28.0,
#    'BBTYPE': 'I',
#    'ETHNICITY': 'Caucasian',
#    'GENDER': 'M',
#    'LOCATION': 'NC',
#    'SAMPLEID': 1537},
#   122: {'AGE': 39.0,
#    'BBTYPE': 'I',
#    'ETHNICITY': 'Caucasian',
#    'GENDER': 'F',
#    'LOCATION': 'NC',
#    'SAMPLEID': 1539},
#   123: {'AGE': 30.0,
#    'BBTYPE': 'I',
#    'ETHNICITY': 'Caucasian',
#    'GENDER': 'M',
#    'LOCATION': 'NC',
#    'SAMPLEID': 1540},
#   124: {'AGE': 26.0,
#    'BBTYPE': 'I',
#    'ETHNICITY': 'Caucasian',
#    'GENDER': 'F',
#    'LOCATION': 'NC',
#    'SAMPLEID': 1541},
#   125: {'AGE': 36.0,
#    'BBTYPE': 'I',
#    'ETHNICITY': 'Caucasian',
#    'GENDER': 'M',
#    'LOCATION': 'NC',
#    'SAMPLEID': 1542},
#   126: {'AGE': 34.0,
#    'BBTYPE': 'I',
#    'ETHNICITY': 'Caucasian',
#    'GENDER': 'F',
#    'LOCATION': 'NC',
#    'SAMPLEID': 1543},
#   127: {'AGE': 33.0,
#    'BBTYPE': 'I',
#    'ETHNICITY': 'Caucasian',
#    'GENDER': 'F',
#    'LOCATION': 'NC',
#    'SAMPLEID': 1544},
#   128: {'AGE': 39.0,
#    'BBTYPE': 'I',
#    'ETHNICITY': 'Caucasian',
#    'GENDER': 'F',
#    'LOCATION': 'NC',
#    'SAMPLEID': 1545},
#   129: {'AGE': 34.0,
#    'BBTYPE': 'I',
#    'ETHNICITY': 'Caucasian',
#    'GENDER': 'M',
#    'LOCATION': 'NC',
#    'SAMPLEID': 1546},
#   130: {'AGE': 38.0,
#    'BBTYPE': 'I',
#    'ETHNICITY': nan,
#    'GENDER': 'M',
#    'LOCATION': 'NC',
#    'SAMPLEID': 1547},
#   131: {'AGE': 6.0,
#    'BBTYPE': 'I',
#    'ETHNICITY': 'Caucasian',
#    'GENDER': 'M',
#    'LOCATION': 'NC',
#    'SAMPLEID': 1548},
#   132: {'AGE': 37.0,
#    'BBTYPE': 'I',
#    'ETHNICITY': 'Caucasian',
#    'GENDER': 'F',
#    'LOCATION': 'NC',
#    'SAMPLEID': 1549},
#   133: {'AGE': 29.0,
#    'BBTYPE': 'I',
#    'ETHNICITY': 'Caucasian',
#    'GENDER': 'F',
#    'LOCATION': 'NC',
#    'SAMPLEID': 1550},
#   134: {'AGE': 26.0,
#    'BBTYPE': 'I',
#    'ETHNICITY': 'Caucasian',
#    'GENDER': 'M',
#    'LOCATION': 'NC',
#    'SAMPLEID': 1551},
#   135: {'AGE': 25.0,
#    'BBTYPE': 'I',
#    'ETHNICITY': 'Caucasian',
#    'GENDER': 'M',
#    'LOCATION': 'NC',
#    'SAMPLEID': 1552},
#   136: {'AGE': 50.0,
#    'BBTYPE': 'I',
#    'ETHNICITY': 'Caucasian',
#    'GENDER': 'F',
#    'LOCATION': 'NC',
#    'SAMPLEID': 1553},
#   137: {'AGE': 18.0,
#    'BBTYPE': 'I',
#    'ETHNICITY': 'Caucasian',
#    'GENDER': 'F',
#    'LOCATION': 'NC',
#    'SAMPLEID': 1554},
#   138: {'AGE': 26.0,
#    'BBTYPE': 'I',
#    'ETHNICITY': 'Caucasian',
#    'GENDER': 'M',
#    'LOCATION': 'NC',
#    'SAMPLEID': 1555},
#   139: {'AGE': 34.0,
#    'BBTYPE': 'I',
#    'ETHNICITY': 'Hispanic',
#    'GENDER': 'M',
#    'LOCATION': 'NC',
#    'SAMPLEID': 1556},
#   140: {'AGE': 26.0,
#    'BBTYPE': 'I',
#    'ETHNICITY': 'Caucasian',
#    'GENDER': 'F',
#    'LOCATION': 'NC',
#    'SAMPLEID': 1557},
#   141: {'AGE': 26.0,
#    'BBTYPE': 'I',
#    'ETHNICITY': 'Caucasian',
#    'GENDER': 'M',
#    'LOCATION': 'NC',
#    'SAMPLEID': 1558},
#   142: {'AGE': 31.0,
#    'BBTYPE': 'I',
#    'ETHNICITY': 'Caucasian',
#    'GENDER': 'M',
#    'LOCATION': 'NC',
#    'SAMPLEID': 1561},
#   143: {'AGE': 39.0,
#    'BBTYPE': 'I',
#    'ETHNICITY': 'Caucasian',
#    'GENDER': 'M',
#    'LOCATION': 'MT',
#    'SAMPLEID': 1562},
#   144: {'AGE': 31.0,
#    'BBTYPE': 'I',
#    'ETHNICITY': 'Caucasian',
#    'GENDER': 'F',
#    'LOCATION': 'MT',
#    'SAMPLEID': 1563},
#   145: {'AGE': 36.0,
#    'BBTYPE': 'I',
#    'ETHNICITY': 'Caucasian',
#    'GENDER': 'F',
#    'LOCATION': 'NC',
#    'SAMPLEID': 1564},
#   146: {'AGE': 33.0,
#    'BBTYPE': 'I',
#    'ETHNICITY': 'Caucasian',
#    'GENDER': 'F',
#    'LOCATION': 'NC',
#    'SAMPLEID': 1572},
#   147: {'AGE': 53.0,
#    'BBTYPE': 'I',
#    'ETHNICITY': 'Caucasian',
#    'GENDER': 'M',
#    'LOCATION': 'NC',
#    'SAMPLEID': 1573},
#   148: {'AGE': 30.0,
#    'BBTYPE': 'I',
#    'ETHNICITY': 'Caucasian',
#    'GENDER': 'M',
#    'LOCATION': 'OK',
#    'SAMPLEID': 1574},
#   149: {'AGE': 33.0,
#    'BBTYPE': 'I',
#    'ETHNICITY': 'Caucasian',
#    'GENDER': 'F',
#    'LOCATION': 'NC',
#    'SAMPLEID': 1576},
#   150: {'AGE': 26.0,
#    'BBTYPE': 'I',
#    'ETHNICITY': 'Caucasian',
#    'GENDER': 'M',
#    'LOCATION': 'NC',
#    'SAMPLEID': 1577},
#   151: {'AGE': 22.0,
#    'BBTYPE': 'I',
#    'ETHNICITY': 'Asian(American)',
#    'GENDER': 'F',
#    'LOCATION': 'NC',
#    'SAMPLEID': 1581},
#   152: {'AGE': 22.0,
#    'BBTYPE': 'I',
#    'ETHNICITY': 'Caucasian',
#    'GENDER': 'F',
#    'LOCATION': 'NC',
#    'SAMPLEID': 1601}}]

# %%
bbb_meta_json = bbb_meta_clean.to_json(orient='index')

# %%
bbb_meta_json
# Out:
# '{"0":{"AGE":24.0,"BBTYPE":"I","ETHNICITY":"Caucasian","GENDER":"F","LOCATION":"Beaufort\\/NC","SAMPLEID":940},"1":{"AGE":34.0,"BBTYPE":"I","ETHNICITY":"Caucasian\\/Midleastern","GENDER":"F","LOCATION":"Chicago\\/IL","SAMPLEID":941},"2":{"AGE":49.0,"BBTYPE":"I","ETHNICITY":"Caucasian","GENDER":"F","LOCATION":"Omaha\\/NE","SAMPLEID":943},"3":{"AGE":44.0,"BBTYPE":"I","ETHNICITY":"European","GENDER":"M","LOCATION":"NewHaven\\/CT","SAMPLEID":944},"4":{"AGE":48.0,"BBTYPE":"I","ETHNICITY":"Caucasian","GENDER":"F","LOCATION":"Philidelphia\\/PA","SAMPLEID":945},"5":{"AGE":42.0,"BBTYPE":"I","ETHNICITY":"Caucasian","GENDER":"F","LOCATION":"Deerfield\\/MA","SAMPLEID":946},"6":{"AGE":49.0,"BBTYPE":"I","ETHNICITY":"Caucasian","GENDER":"M","LOCATION":"ChapelHill\\/NC","SAMPLEID":947},"7":{"AGE":20.0,"BBTYPE":"I","ETHNICITY":"Caucasian","GENDER":"M","LOCATION":"ChapelHill\\/NC","SAMPLEID":948},"8":{"AGE":51.0,"BBTYPE":"I","ETHNICITY":"Caucasian","GENDER":"F","LOCATION":"Durham\\/NC","SAMPLEID":949},"9":{"AGE":51.0,"BBTYPE":"I","ETHNICITY":"Caucasian","GENDER":"M","LOCATION":"NewYork\\/NY","SAMPLEID":950},"10":{"AGE":51.0,"BBTYPE":"I","ETHNICITY":"Caucasian","GENDER":"F","LOCATION":"Seattle\\/WA","SAMPLEID":952},"11":{"AGE":38.0,"BBTYPE":"I","ETHNICITY":"Caucasian","GENDER":"F","LOCATION":"Chicago\\/IL","SAMPLEID":953},"12":{"AGE":26.0,"BBTYPE":"I","ETHNICITY":"Caucasian","GENDER":"M","LOCATION":"NewYork\\/NY","SAMPLEID":954},"13":{"AGE":27.0,"BBTYPE":"I","ETHNICITY":"Caucasian","GENDER":"F","LOCATION":"NewYork\\/NY","SAMPLEID":955},"14":{"AGE":16.0,"BBTYPE":"I","ETHNICITY":"Caucasian","GENDER":"M","LOCATION":"Jacksonville\\/NC","SAMPLEID":956},"15":{"AGE":43.0,"BBTYPE":"I","ETHNICITY":"Caucasian","GENDER":"M","LOCATION":"Wilmington\\/NC","SAMPLEID":958},"16":{"AGE":40.0,"BBTYPE":"I","ETHNICITY":"Caucasian","GENDER":"M","LOCATION":"Carrboro\\/NC","SAMPLEID":959},"17":{"AGE":48.0,"BBTYPE":"I","ETHNICITY":"Caucasian","GENDER":"M","LOCATION":"Lexington\\/NC","SAMPLEID":960},"18":{"AGE":35.0,"BBTYPE":"i","ETHNICITY":"Caucasian","GENDER":"F","LOCATION":"Edmonton,AB","SAMPLEID":961},"19":{"AGE":56.0,"BBTYPE":"i","ETHNICITY":"Caucasian","GENDER":"F","LOCATION":"Washington,DC","SAMPLEID":962},"20":{"AGE":33.0,"BBTYPE":"I","ETHNICITY":"Caucasian","GENDER":"F","LOCATION":"Ithaca\\/NY","SAMPLEID":963},"21":{"AGE":43.0,"BBTYPE":"I","ETHNICITY":"Caucasian","GENDER":"F","LOCATION":"UK\\/London","SAMPLEID":964},"22":{"AGE":56.0,"BBTYPE":"I","ETHNICITY":"Caucasian","GENDER":"M","LOCATION":"Needham\\/MA","SAMPLEID":966},"23":{"AGE":43.0,"BBTYPE":"I","ETHNICITY":"Caucasian\\/Jewish","GENDER":"F","LOCATION":"ChapelHill\\/NC","SAMPLEID":967},"24":{"AGE":38.0,"BBTYPE":"I","ETHNICITY":"Caucasian","GENDER":"F","LOCATION":"St.Louis\\/MI","SAMPLEID":968},"25":{"AGE":31.0,"BBTYPE":"I","ETHNICITY":"Caucasian\\/Asian","GENDER":"F","LOCATION":"ChevyChase\\/MD","SAMPLEID":969},"26":{"AGE":42.0,"BBTYPE":"i","ETHNICITY":"Caucasian","GENDER":"F","LOCATION":"SanDiego\\/CA","SAMPLEID":970},"27":{"AGE":36.0,"BBTYPE":"I","ETHNICITY":"Asian(South)","GENDER":"M","LOCATION":"SantaBarbara\\/CA","SAMPLEID":971},"28":{"AGE":31.0,"BBTYPE":"I","ETHNICITY":"Caucasian","GENDER":"F","LOCATION":"Charlotte\\/NC","SAMPLEID":972},"29":{"AGE":4.0,"BBTYPE":"I","ETHNICITY":"Caucasian","GENDER":"F","LOCATION":"Charlotte\\/NC","SAMPLEID":973},"30":{"AGE":57.0,"BBTYPE":"I","ETHNICITY":"Caucasian","GENDER":"F","LOCATION":"Raleigh\\/NC","SAMPLEID":974},"31":{"AGE":60.0,"BBTYPE":"I","ETHNICITY":"Caucasian","GENDER":"F","LOCATION":"NewCanaan\\/CT","SAMPLEID":975},"32":{"AGE":21.0,"BBTYPE":null,"ETHNICITY":"Hispanic","GENDER":"F","LOCATION":"Durham\\/NC","SAMPLEID":978},"33":{"AGE":34.0,"BBTYPE":"I","ETHNICITY":"Caucasian","GENDER":"M","LOCATION":null,"SAMPLEID":1233},"34":{"AGE":null,"BBTYPE":"I","ETHNICITY":"Caucasian","GENDER":"F","LOCATION":null,"SAMPLEID":1234},"35":{"AGE":43.0,"BBTYPE":null,"ETHNICITY":"Caucasian","GENDER":"F","LOCATION":null,"SAMPLEID":1235},"36":{"AGE":54.0,"BBTYPE":null,"ETHNICI ...
