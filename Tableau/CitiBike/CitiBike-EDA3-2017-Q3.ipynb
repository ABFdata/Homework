# %%
import pandas as pd
import pandas_profiling as pp
import numpy as np
from IPython.core.interactiveshell import InteractiveShell
InteractiveShell.ast_node_interactivity = "all"
import warnings
warnings.filterwarnings('ignore')

# %%
# read in a 2013 dataset to print columns
old2013 = pd.read_csv('TripData/TripData_2013_07.csv')

# %%
# The column names have been updated for 2017
old2013.columns.tolist()
# Out:
# ['tripduration',
#  'starttime',
#  'stoptime',
#  'start station id',
#  'start station name',
#  'start station latitude',
#  'start station longitude',
#  'end station id',
#  'end station name',
#  'end station latitude',
#  'end station longitude',
#  'bikeid',
#  'usertype',
#  'birth year',
#  'gender']

# %%
TripData1 = pd.read_csv('TripData/TripData_2017_07.csv')
TripData2 = pd.read_csv('TripData/TripData_2017_08.csv')
TripData3 = pd.read_csv('TripData/TripData_2017_09.csv')

# %%
TripData1.head(2)
TripData1.shape
# Out:
#    tripduration            starttime             stoptime  start station id  \
# 0           364  2017-07-01 00:00:00  2017-07-01 00:06:05               539
# 1          2142  2017-07-01 00:00:03  2017-07-01 00:35:46               293
#
#                start station name  start station latitude  \
# 0  Metropolitan Ave & Bedford Ave               40.715348
# 1           Lafayette St & E 8 St               40.730207
#
#    start station longitude  end station id          end station name  \
# 0               -73.960241            3107  Bedford Ave & Nassau Ave
# 1               -73.991026            3425         2 Ave  & E 104 St
#
#    end station latitude  end station longitude  bikeid    usertype  \
# 0             40.723117             -73.952123   14744  Subscriber
# 1             40.789210             -73.943708   19587  Subscriber
#
#    birth year  gender
# 0      1986.0       1
# 1      1981.0       1
# (1735599, 15)

# %%
TripData2.head(2)
TripData2.shape
# Out:
#    tripduration            starttime             stoptime  start station id  \
# 0          2110  2017-08-01 00:00:00  2017-08-01 00:35:11               470
# 1           160  2017-08-01 00:00:10  2017-08-01 00:02:51               348
#
#        start station name  start station latitude  start station longitude  \
# 0         W 20 St & 8 Ave               40.743453               -74.000040
# 1  W Broadway & Spring St               40.724910               -74.001547
#
#    end station id          end station name  end station latitude  \
# 0            3289   W 90 St & Amsterdam Ave             40.790179
# 1             151  Cleveland Pl & Spring St             40.722104
#
#    end station longitude  bikeid    usertype  birth year  gender
# 0             -73.972889   20954  Subscriber      1978.0       2
# 1             -73.997249   15164  Subscriber      1978.0       1
# (1816498, 15)

# %%
TripData3.head(2)
TripData3.shape
# Out:
#    tripduration            starttime             stoptime  start station id  \
# 0           362  2017-09-01 00:00:17  2017-09-01 00:06:19              3331
# 1           188  2017-09-01 00:00:21  2017-09-01 00:03:30              3101
#
#         start station name  start station latitude  start station longitude  \
# 0  Riverside Dr & W 104 St               40.801343               -73.971146
# 1    N 12 St & Bedford Ave               40.720798               -73.954847
#
#    end station id          end station name  end station latitude  \
# 0            3328  W 100 St & Manhattan Ave             40.795000
# 1            3100    Nassau Ave & Newell St             40.724813
#
#    end station longitude  bikeid    usertype  birth year  gender
# 0             -73.964500   14530  Subscriber      1993.0       1
# 1             -73.947526   15475  Subscriber      1988.0       1
# (1878098, 15)

# %%
# merge all 3 csvs
TripData_merge = pd.concat([TripData1, TripData2, TripData3])

# %%
TripData_merge.reset_index(inplace=True)

# %%
TripData_merge.tail()
TripData_merge.shape
# Out:
#            index  tripduration            starttime             stoptime  \
# 5430190  1878093           621  2017-09-30 23:59:30  2017-10-01 00:09:52
# 5430191  1878094           656  2017-09-30 23:59:33  2017-10-01 00:10:30
# 5430192  1878095           516  2017-09-30 23:59:40  2017-10-01 00:08:16
# 5430193  1878096          1039  2017-09-30 23:59:49  2017-10-01 00:17:08
# 5430194  1878097           621  2017-09-30 23:59:52  2017-10-01 00:10:13
#
#          start station id           start station name  \
# 5430190              3366      West End Ave & W 107 St
# 5430191              3163  Central Park West & W 68 St
# 5430192              3224          W 13 St & Hudson St
# 5430193              3167      Amsterdam Ave & W 73 St
# 5430194              3462              E 44 St & 2 Ave
#
#          start station latitude  start station longitude  end station id  \
# 5430190               40.802117               -73.968181            3540
# 5430191               40.773407               -73.977825             479
# 5430192               40.739974               -74.005139             382
# 5430193               40.779668               -73.980930            3336
# 5430194               40.751184               -73.971387             237
#
#                    end station name  end station latitude  \
# 5430190  Morningside Ave & W 123 St             40.810000
# 5430191             9 Ave & W 45 St             40.760193
# 5430192     University Pl & E 14 St             40.734927
# 5430193       E 97 St & Madison Ave             40.787801
# 5430194             E 11 St & 2 Ave             40.730473
#
#          end station longitude  bikeid    usertype  birth year  gender
# 5430190             -73.955151   28812  Subscriber      1980.0       2
# 5430191             -73.991255   19088  Subscriber      1986.0       1
# 5430192             -73.992005   29922  Subscriber         NaN       0
# 5430193             -73.953559   26007  Subscriber      1990.0       1
# 5430194             -73.986724   29366  Subscriber      1996.0       2
# (5430195, 16)

# %%
TripData_merge2 = TripData_merge.drop('index', axis=1)

# %%
TripData_merge2.head()
TripData_merge2.shape
# Out:
#    tripduration            starttime             stoptime  start station id  \
# 0           364  2017-07-01 00:00:00  2017-07-01 00:06:05               539
# 1          2142  2017-07-01 00:00:03  2017-07-01 00:35:46               293
# 2           328  2017-07-01 00:00:08  2017-07-01 00:05:37              3242
# 3          2530  2017-07-01 00:00:11  2017-07-01 00:42:22              2002
# 4          2534  2017-07-01 00:00:15  2017-07-01 00:42:29              2002
#
#                start station name  start station latitude  \
# 0  Metropolitan Ave & Bedford Ave               40.715348
# 1           Lafayette St & E 8 St               40.730207
# 2      Schermerhorn St & Court St               40.691029
# 3    Wythe Ave & Metropolitan Ave               40.716887
# 4    Wythe Ave & Metropolitan Ave               40.716887
#
#    start station longitude  end station id          end station name  \
# 0               -73.960241            3107  Bedford Ave & Nassau Ave
# 1               -73.991026            3425         2 Ave  & E 104 St
# 2               -73.991834            3397      Court St & Nelson St
# 3               -73.963198             398  Atlantic Ave & Furman St
# 4               -73.963198             398  Atlantic Ave & Furman St
#
#    end station latitude  end station longitude  bikeid    usertype  \
# 0             40.723117             -73.952123   14744  Subscriber
# 1             40.789210             -73.943708   19587  Subscriber
# 2             40.676395             -73.998699   27937  Subscriber
# 3             40.691652             -73.999979   26066  Subscriber
# 4             40.691652             -73.999979   29408  Subscriber
#
#    birth year  gender
# 0      1986.0       1
# 1      1981.0       1
# 2      1984.0       2
# 3      1985.0       1
# 4      1982.0       2
# (5430195, 15)

# %%
TripData_merge2.isnull().head()
TripData_merge2.isnull().tail()
# Out:
#    tripduration  starttime  stoptime  start station id  start station name  \
# 0         False      False     False             False               False
# 1         False      False     False             False               False
# 2         False      False     False             False               False
# 3         False      False     False             False               False
# 4         False      False     False             False               False
#
#    start station latitude  start station longitude  end station id  \
# 0                   False                    False           False
# 1                   False                    False           False
# 2                   False                    False           False
# 3                   False                    False           False
# 4                   False                    False           False
#
#    end station name  end station latitude  end station longitude  bikeid  \
# 0             False                 False                  False   False
# 1             False                 False                  False   False
# 2             False                 False                  False   False
# 3             False                 False                  False   False
# 4             False                 False                  False   False
#
#    usertype  birth year  gender
# 0     False       False   False
# 1     False       False   False
# 2     False       False   False
# 3     False       False   False
# 4     False       False   False
#          tripduration  starttime  stoptime  start station id  \
# 5430190         False      False     False             False
# 5430191         False      False     False             False
# 5430192         False      False     False             False
# 5430193         False      False     False             False
# 5430194         False      False     False             False
#
#          start station name  start station latitude  start station longitude  \
# 5430190               False                   False                    False
# 5430191               False                   False                    False
# 5430192               False                   False                    False
# 5430193               False                   False                    False
# 5430194               False                   False                    False
#
#          end station id  end station name  end station latitude  \
# 5430190           False             False                 False
# 5430191           False             False                 False
# 5430192           False             False                 False
# 5430193           False             False                 False
# 5430194           False             False                 False
#
#          end station longitude  bikeid  usertype  birth year  gender
# 5430190                  False   False     False       False   False
# 5430191                  False   False     False       False   False
# 5430192                  False   False     False        True   False
# 5430193                  False   False     False       False   False
# 5430194                  False   False     False       False   False

# %% [markdown]
# ### We have missing values in the Birth Year Column

# %%
# this script tells us the number of missing values in each column
TripData_merge2.isnull().sum()
# Out:
# tripduration                    0
# starttime                       0
# stoptime                        0
# start station id                0
# start station name              0
# start station latitude          0
# start station longitude         0
# end station id                  0
# end station name                0
# end station latitude            0
# end station longitude           0
# bikeid                          0
# usertype                        0
# birth year                 660780
# gender                          0
# dtype: int64

# %%
TripData_merge2.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5430195 entries, 0 to 5430194
# Data columns (total 15 columns):
# tripduration               int64
# starttime                  object
# stoptime                   object
# start station id           int64
# start station name         object
# start station latitude     float64
# start station longitude    float64
# end station id             int64
# end station name           object
# end station latitude       float64
# end station longitude      float64
# bikeid                     int64
# usertype                   object
# birth year                 float64
# gender                     int64
# dtypes: float64(5), int64(5), object(5)
# memory usage: 621.4+ MB

# %%
# Drop the missing values
# This will drop a row if any of its values are missing
TripData_merge3 = TripData_merge2.dropna(how='any')

# %%
TripData_merge3.tail()
TripData_merge3.shape
# Out:
#          tripduration            starttime             stoptime  \
# 5430189           672  2017-09-30 23:59:31  2017-10-01 00:10:43
# 5430190           621  2017-09-30 23:59:30  2017-10-01 00:09:52
# 5430191           656  2017-09-30 23:59:33  2017-10-01 00:10:30
# 5430193          1039  2017-09-30 23:59:49  2017-10-01 00:17:08
# 5430194           621  2017-09-30 23:59:52  2017-10-01 00:10:13
#
#          start station id           start station name  \
# 5430189              3163  Central Park West & W 68 St
# 5430190              3366      West End Ave & W 107 St
# 5430191              3163  Central Park West & W 68 St
# 5430193              3167      Amsterdam Ave & W 73 St
# 5430194              3462              E 44 St & 2 Ave
#
#          start station latitude  start station longitude  end station id  \
# 5430189               40.773407               -73.977825             479
# 5430190               40.802117               -73.968181            3540
# 5430191               40.773407               -73.977825             479
# 5430193               40.779668               -73.980930            3336
# 5430194               40.751184               -73.971387             237
#
#                    end station name  end station latitude  \
# 5430189             9 Ave & W 45 St             40.760193
# 5430190  Morningside Ave & W 123 St             40.810000
# 5430191             9 Ave & W 45 St             40.760193
# 5430193       E 97 St & Madison Ave             40.787801
# 5430194             E 11 St & 2 Ave             40.730473
#
#          end station longitude  bikeid    usertype  birth year  gender
# 5430189             -73.991255   30519  Subscriber      1986.0       2
# 5430190             -73.955151   28812  Subscriber      1980.0       2
# 5430191             -73.991255   19088  Subscriber      1986.0       1
# 5430193             -73.953559   26007  Subscriber      1990.0       1
# 5430194             -73.986724   29366  Subscriber      1996.0       2
# (4769415, 15)

# %%
TripData_merge3.reset_index(drop=True, inplace=True)
TripData_merge3.tail(2)
TripData_merge3.shape
# Out:
#          tripduration            starttime             stoptime  \
# 4769413          1039  2017-09-30 23:59:49  2017-10-01 00:17:08
# 4769414           621  2017-09-30 23:59:52  2017-10-01 00:10:13
#
#          start station id       start station name  start station latitude  \
# 4769413              3167  Amsterdam Ave & W 73 St               40.779668
# 4769414              3462          E 44 St & 2 Ave               40.751184
#
#          start station longitude  end station id       end station name  \
# 4769413               -73.980930            3336  E 97 St & Madison Ave
# 4769414               -73.971387             237        E 11 St & 2 Ave
#
#          end station latitude  end station longitude  bikeid    usertype  \
# 4769413             40.787801             -73.953559   26007  Subscriber
# 4769414             40.730473             -73.986724   29366  Subscriber
#
#          birth year  gender
# 4769413      1990.0       1
# 4769414      1996.0       2
# (4769415, 15)

# %%
# Change the column headers to reflect the same columns in Q1
TripData_merge4 = TripData_merge3.rename(columns={'tripduration': 'Trip Duration',
                               'starttime': 'Start Time',
                               'stoptime': 'Stop Time',
                               'start station id': 'Start Station ID',
                               'start station name': 'Start Station Name',
                               'start station latitude': 'Start Station Latitude',
                               'start station longitude': 'Start Station Longitude',
                               'end station id': 'End Station ID',
                               'end station name': 'End Station Name',
                               'end station latitude': 'End Station Latitude',
                               'end station longitude': 'End Station Longitude',
                               'bikeid': 'Bike ID',
                               'usertype': 'User Type',
                               'birth year': 'Birth Year',
                               'gender': 'Gender'})

# %%
TripData_merge4.head(2)
TripData_merge4.shape
# Out:
#    Trip Duration           Start Time            Stop Time  Start Station ID  \
# 0            364  2017-07-01 00:00:00  2017-07-01 00:06:05               539
# 1           2142  2017-07-01 00:00:03  2017-07-01 00:35:46               293
#
#                Start Station Name  Start Station Latitude  \
# 0  Metropolitan Ave & Bedford Ave               40.715348
# 1           Lafayette St & E 8 St               40.730207
#
#    Start Station Longitude  End Station ID          End Station Name  \
# 0               -73.960241            3107  Bedford Ave & Nassau Ave
# 1               -73.991026            3425         2 Ave  & E 104 St
#
#    End Station Latitude  End Station Longitude  Bike ID   User Type  \
# 0             40.723117             -73.952123    14744  Subscriber
# 1             40.789210             -73.943708    19587  Subscriber
#
#    Birth Year  Gender
# 0      1986.0       1
# 1      1981.0       1
# (4769415, 15)

# %%
# set the year (current year for data series is 2017) - we'll use year to get the age
year = 2017

# %%
def get_age(i):
    return year - i

test_age = []

for i in TripData_merge4['Birth Year']:
    test_age.append(get_age(int(i)))

# %%
print(len(test_age))
# Out:
# 4769415

# %%
test_age[0]
# Out:
# 31

# %%
# make test_age into a series
# set it to a variable "age" which will be the new column "age" that we add to the dataframe
age = pd.Series(test_age)

# %%
# now insert age into the df as a column 
# loc=14 will set the location at index14
# value=age - sets the values of the column to the pd series list we made above
TripData_merge4.insert(loc=14, column='Age', value=age)

# %%
TripData_merge4.head(2)
TripData_merge4.tail(2)
TripData_merge4.shape
# Out:
#    Trip Duration           Start Time            Stop Time  Start Station ID  \
# 0            364  2017-07-01 00:00:00  2017-07-01 00:06:05               539
# 1           2142  2017-07-01 00:00:03  2017-07-01 00:35:46               293
#
#                Start Station Name  Start Station Latitude  \
# 0  Metropolitan Ave & Bedford Ave               40.715348
# 1           Lafayette St & E 8 St               40.730207
#
#    Start Station Longitude  End Station ID          End Station Name  \
# 0               -73.960241            3107  Bedford Ave & Nassau Ave
# 1               -73.991026            3425         2 Ave  & E 104 St
#
#    End Station Latitude  End Station Longitude  Bike ID   User Type  \
# 0             40.723117             -73.952123    14744  Subscriber
# 1             40.789210             -73.943708    19587  Subscriber
#
#    Birth Year  Age  Gender
# 0      1986.0   31       1
# 1      1981.0   36       1
#          Trip Duration           Start Time            Stop Time  \
# 4769413           1039  2017-09-30 23:59:49  2017-10-01 00:17:08
# 4769414            621  2017-09-30 23:59:52  2017-10-01 00:10:13
#
#          Start Station ID       Start Station Name  Start Station Latitude  \
# 4769413              3167  Amsterdam Ave & W 73 St               40.779668
# 4769414              3462          E 44 St & 2 Ave               40.751184
#
#          Start Station Longitude  End Station ID       End Station Name  \
# 4769413               -73.980930            3336  E 97 St & Madison Ave
# 4769414               -73.971387             237        E 11 St & 2 Ave
#
#          End Station Latitude  End Station Longitude  Bike ID   User Type  \
# 4769413             40.787801             -73.953559    26007  Subscriber
# 4769414             40.730473             -73.986724    29366  Subscriber
#
#          Birth Year  Age  Gender
# 4769413      1990.0   27       1
# 4769414      1996.0   21       2
# (4769415, 16)

# %% [markdown]
# ### Our new merged / clean data set with age has zero null values

# %%
# this script tells us the number of missing values in each column
TripData_merge4.isnull().sum()
# Out:
# Trip Duration              0
# Start Time                 0
# Stop Time                  0
# Start Station ID           0
# Start Station Name         0
# Start Station Latitude     0
# Start Station Longitude    0
# End Station ID             0
# End Station Name           0
# End Station Latitude       0
# End Station Longitude      0
# Bike ID                    0
# User Type                  0
# Birth Year                 0
# Age                        0
# Gender                     0
# dtype: int64

# %% [markdown]
# <hr>

# %% [markdown]
# <br>
# # Section to calculate distance between stations - using TripData_merge4

# %%
station_distance = TripData_merge4
station_distance.iloc[0:2] # iloc returns the first two rows (i=index location). this is also the same as .head(2)
station_distance.shape
# Out:
#    Trip Duration           Start Time            Stop Time  Start Station ID  \
# 0            364  2017-07-01 00:00:00  2017-07-01 00:06:05               539
# 1           2142  2017-07-01 00:00:03  2017-07-01 00:35:46               293
#
#                Start Station Name  Start Station Latitude  \
# 0  Metropolitan Ave & Bedford Ave               40.715348
# 1           Lafayette St & E 8 St               40.730207
#
#    Start Station Longitude  End Station ID          End Station Name  \
# 0               -73.960241            3107  Bedford Ave & Nassau Ave
# 1               -73.991026            3425         2 Ave  & E 104 St
#
#    End Station Latitude  End Station Longitude  Bike ID   User Type  \
# 0             40.723117             -73.952123    14744  Subscriber
# 1             40.789210             -73.943708    19587  Subscriber
#
#    Birth Year  Age  Gender
# 0      1986.0   31       1
# 1      1981.0   36       1
# (4769415, 16)

# %%
station_distance.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4769415 entries, 0 to 4769414
# Data columns (total 16 columns):
# Trip Duration              int64
# Start Time                 object
# Stop Time                  object
# Start Station ID           int64
# Start Station Name         object
# Start Station Latitude     float64
# Start Station Longitude    float64
# End Station ID             int64
# End Station Name           object
# End Station Latitude       float64
# End Station Longitude      float64
# Bike ID                    int64
# User Type                  object
# Birth Year                 float64
# Age                        int64
# Gender                     int64
# dtypes: float64(5), int64(6), object(5)
# memory usage: 582.2+ MB

# %%
# this library helps you calculate distance by coordinates
import geopy.distance

# %%
# create an empty list to append start coords
start_lat = []
start_lon = []

# %%
# iterate through 'start station latitude' and append to start
for i in station_distance['Start Station Latitude']:
    start_lat.append(i)

# iterate through start station longitude
for i in station_distance['Start Station Longitude']:
    start_lon.append(i)

# %%
# print to make sure all the lat coords and long coords were added to the list
print (len(start_lat))
print (len(start_lon))
# Out:
# 4769415
# 4769415

# %%
# convert the start / end coords to str objects
station_distance['Start Station Latitude'] = station_distance['Start Station Latitude'].astype(str)
station_distance['Start Station Longitude'] = station_distance['Start Station Longitude'].astype(str)
station_distance['End Station Latitude'] = station_distance['End Station Latitude'].astype(str)
station_distance['End Station Longitude'] = station_distance['End Station Longitude'].astype(str)

station_distance.info() # will print the datatype
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4769415 entries, 0 to 4769414
# Data columns (total 16 columns):
# Trip Duration              int64
# Start Time                 object
# Stop Time                  object
# Start Station ID           int64
# Start Station Name         object
# Start Station Latitude     object
# Start Station Longitude    object
# End Station ID             int64
# End Station Name           object
# End Station Latitude       object
# End Station Longitude      object
# Bike ID                    int64
# User Type                  object
# Birth Year                 float64
# Age                        int64
# Gender                     int64
# dtypes: float64(1), int64(6), object(9)
# memory usage: 582.2+ MB

# %%
# this concats the start lat and lon values and adds to a new col
station_distance['Start Coordinates'] = station_distance['Start Station Latitude'].astype(str) + " , " + \
station_distance['Start Station Longitude']

# %%
# this concats the end lat and end lon values and adds to a new col
station_distance['End Coordinates'] = station_distance['End Station Latitude'].astype(str) + " , " + \
station_distance['End Station Longitude']

# %%
station_distance.head(2)
station_distance.shape
# Out:
#    Trip Duration           Start Time            Stop Time  Start Station ID  \
# 0            364  2017-07-01 00:00:00  2017-07-01 00:06:05               539
# 1           2142  2017-07-01 00:00:03  2017-07-01 00:35:46               293
#
#                Start Station Name Start Station Latitude  \
# 0  Metropolitan Ave & Bedford Ave            40.71534825
# 1           Lafayette St & E 8 St          40.7302066053
#
#   Start Station Longitude  End Station ID          End Station Name  \
# 0            -73.96024116            3107  Bedford Ave & Nassau Ave
# 1          -73.9910262823            3425         2 Ave  & E 104 St
#
#   End Station Latitude End Station Longitude  Bike ID   User Type  Birth Year  \
# 0          40.72311651          -73.95212324    14744  Subscriber      1986.0
# 1           40.7892105          -73.94370784    19587  Subscriber      1981.0
#
#    Age  Gender               Start Coordinates             End Coordinates
# 0   31       1      40.71534825 , -73.96024116  40.72311651 , -73.95212324
# 1   36       1  40.7302066053 , -73.9910262823   40.7892105 , -73.94370784
# (4769415, 18)

# %%
# take the start coordinates and end coordinates columns and turn them into lists
start_coord_list = station_distance['Start Coordinates'].tolist()
end_coord_list = station_distance['End Coordinates'].tolist()

# %%
# print to make sure the length is the same
# set them to variables so we can iterate through the object below
len_start_coord_list = len(start_coord_list)
len_end_coord_list = len (end_coord_list)

len_start_coord_list
len_end_coord_list
# Out:
# 4769415
# 4769415

# %%
# lets test to see that the coords were added to the empty lists
# test by position in list
test0 = start_coord_list[5]
test1 = end_coord_list[5]
print(test0)
print(test1)
# Out:
# 40.71605866 , -73.99190759
# 40.714215 , -73.981346

# %% [markdown]
# ### Inspect station_distance by using loc and iloc

# %%
station_distance.columns.tolist()
# Out:
# ['Trip Duration',
#  'Start Time',
#  'Stop Time',
#  'Start Station ID',
#  'Start Station Name',
#  'Start Station Latitude',
#  'Start Station Longitude',
#  'End Station ID',
#  'End Station Name',
#  'End Station Latitude',
#  'End Station Longitude',
#  'Bike ID',
#  'User Type',
#  'Birth Year',
#  'Age',
#  'Gender',
#  'Start Coordinates',
#  'End Coordinates']

# %%
# print out a flitered df for station_distance displaying start station name, 
# end station name, start coordinates, end coordinates
# REMEMBER - loc indexes by column name
station_distance.loc[:, ['Start Station Name', 'End Station Name', 'Start Coordinates', 'End Coordinates']].head(2)
# Out:
#                Start Station Name          End Station Name  \
# 0  Metropolitan Ave & Bedford Ave  Bedford Ave & Nassau Ave
# 1           Lafayette St & E 8 St         2 Ave  & E 104 St
#
#                 Start Coordinates             End Coordinates
# 0      40.71534825 , -73.96024116  40.72311651 , -73.95212324
# 1  40.7302066053 , -73.9910262823   40.7892105 , -73.94370784

# %%
# REMEMBER - iloc - indexes by column position number
station_distance.iloc[0:2, [0,3,6,7]]

# iloc range 0-4 is exclusive - here, the columns will end at Start Station ID not Start Staion Name
# loc - is inclusive for range 0-4, the columns will include the 4th position
station_distance.iloc[0:2, 0:4]
# Out:
#    Trip Duration  Start Station ID Start Station Longitude  End Station ID
# 0            364               539            -73.96024116            3107
# 1           2142               293          -73.9910262823            3425
#    Trip Duration           Start Time            Stop Time  Start Station ID
# 0            364  2017-07-01 00:00:00  2017-07-01 00:06:05               539
# 1           2142  2017-07-01 00:00:03  2017-07-01 00:35:46               293

# %% [markdown]
# ### Create a function for geopy

# %%
# create a function to get a list element
def get_start(start_coord_list, position):
    return start_coord_list[position]

# %%
# create a function to get a list element
def get_end(end_coord_list, position):
    return end_coord_list[position]

# %%
def get_distance():
    return geopy.distance.vincenty(get_start(start_coord_list, i), get_end(end_coord_list, i)).miles

# %%
# test code for geopy
start = get_start(start_coord_list, 1)
end = get_end(end_coord_list, 1)

# %%
# test geopy before iterating
geopy.distance.vincenty(start, end).miles # should print the same as get_distance
# Out:
# 4.768703767440751

# %%
# create an empty list to append to
distance_list = []

# iterate through get_distance to get the distance between coordinates
for i in range (0, len_start_coord_list):    
    distance_list.append(get_distance())

# %%
# check to see if distance was added to list
print(len(distance_list))
station_distance.shape
# Out:
# 4769415
# (4769415, 18)

# %%
# make distance_list into a series
# set it to a variable "distance2" which will be the new column "distance" that we add to the dataframe
distance = pd.Series(distance_list)

# %%
# now insert distance2 into the df as a column 
# loc=11 will set the location at index11 after end station longitude
# value=distance2 - sets the values of the column to the pd series list we made above
station_distance.insert(loc=11, column='Distance(Miles)', value=distance)

# %%
station_distance.shape
station_distance.columns
# Out:
# (4769415, 19)
# Index(['Trip Duration', 'Start Time', 'Stop Time', 'Start Station ID',
#        'Start Station Name', 'Start Station Latitude',
#        'Start Station Longitude', 'End Station ID', 'End Station Name',
#        'End Station Latitude', 'End Station Longitude', 'Distance(Miles)',
#        'Bike ID', 'User Type', 'Birth Year', 'Age', 'Gender',
#        'Start Coordinates', 'End Coordinates'],
#       dtype='object')

# %%
station_distance.tail()
station_distance.shape
# Out:
#          Trip Duration           Start Time            Stop Time  \
# 4769410            672  2017-09-30 23:59:31  2017-10-01 00:10:43
# 4769411            621  2017-09-30 23:59:30  2017-10-01 00:09:52
# 4769412            656  2017-09-30 23:59:33  2017-10-01 00:10:30
# 4769413           1039  2017-09-30 23:59:49  2017-10-01 00:17:08
# 4769414            621  2017-09-30 23:59:52  2017-10-01 00:10:13
#
#          Start Station ID           Start Station Name Start Station Latitude  \
# 4769410              3163  Central Park West & W 68 St             40.7734066
# 4769411              3366      West End Ave & W 107 St             40.8021174
# 4769412              3163  Central Park West & W 68 St             40.7734066
# 4769413              3167      Amsterdam Ave & W 73 St          40.7796680901
# 4769414              3462              E 44 St & 2 Ave          40.7511838746
#
#         Start Station Longitude  End Station ID            End Station Name  \
# 4769410            -73.97782542             479             9 Ave & W 45 St
# 4769411          -73.9681805305            3540  Morningside Ave & W 123 St
# 4769412            -73.97782542             479             9 Ave & W 45 St
# 4769413          -73.9809304476            3336       E 97 St & Madison Ave
# 4769414          -73.9713871479             237             E 11 St & 2 Ave
#
#         End Station Latitude End Station Longitude  Distance(Miles)  Bike ID  \
# 4769410          40.76019252           -73.9912551         1.152304    30519
# 4769411                40.81           -73.9551508         0.873261    28812
# 4769412          40.76019252           -73.9912551         1.152304    19088
# 4769413            40.787801            -73.953559         1.541414    26007
# 4769414          40.73047309          -73.98672378         1.640187    29366
#
#           User Type  Birth Year  Age  Gender               Start Coordinates  \
# 4769410  Subscriber      1986.0   31       2       40.7734066 , -73.97782542
# 4769411  Subscriber      1980.0   37       2     40.8021174 , -73.9681805305
# 4769412  Subscriber      1986.0   31       1       40.7734066 , -73.97782542
# 4769413  Subscriber      1990.0   27       1  40.7796680901 , -73.9809304476
# 4769414  Subscriber      1996.0   21       2  40.7511838746 , -73.9713871479
#
#                     End Coordinates
# 4769410   40.76019252 , -73.9912551
# 4769411         40.81 , -73.9551508
# 4769412   40.76019252 , -73.9912551
# 4769413      40.787801 , -73.953559
# 4769414  40.73047309 , -73.98672378
# (4769415, 19)

# %%
# create function to calculate seconds to minutes
seconds = station_distance['Trip Duration'].tolist()
seconds_len = (len(seconds))
minutes_list = []

def get_min():
    return seconds[i] / 60

# %%
# checks the length of the trip duration list that we assigned to seconds, then seconds_len
seconds_len
# Out:
# 4769415

# %%
for i in range(0, seconds_len):
    minutes_list.append(get_min())

# %%
print(len(minutes_list))
# Out:
# 4769415

# %%
# make minutes_list into a series
# set it to a variable "tripduration_minutes" which will be the new column "tripduration_minutes" 
# that we add to the dataframe
tripduration_minutes = pd.Series(minutes_list)

# %%
# now insert tripduration_minutes into the df as a column 
# loc=1 will set the location at index1
# value= tripduration_minutes - sets the values of the column to the pd series list we made above
station_distance.insert(loc=1, column='Trip Duration(Minutes)', value=tripduration_minutes)

# %%
station_distance.tail()
station_distance.shape
# Out:
#          Trip Duration  Trip Duration(Minutes)           Start Time  \
# 4769410            672               11.200000  2017-09-30 23:59:31
# 4769411            621               10.350000  2017-09-30 23:59:30
# 4769412            656               10.933333  2017-09-30 23:59:33
# 4769413           1039               17.316667  2017-09-30 23:59:49
# 4769414            621               10.350000  2017-09-30 23:59:52
#
#                    Stop Time  Start Station ID           Start Station Name  \
# 4769410  2017-10-01 00:10:43              3163  Central Park West & W 68 St
# 4769411  2017-10-01 00:09:52              3366      West End Ave & W 107 St
# 4769412  2017-10-01 00:10:30              3163  Central Park West & W 68 St
# 4769413  2017-10-01 00:17:08              3167      Amsterdam Ave & W 73 St
# 4769414  2017-10-01 00:10:13              3462              E 44 St & 2 Ave
#
#         Start Station Latitude Start Station Longitude  End Station ID  \
# 4769410             40.7734066            -73.97782542             479
# 4769411             40.8021174          -73.9681805305            3540
# 4769412             40.7734066            -73.97782542             479
# 4769413          40.7796680901          -73.9809304476            3336
# 4769414          40.7511838746          -73.9713871479             237
#
#                    End Station Name End Station Latitude  \
# 4769410             9 Ave & W 45 St          40.76019252
# 4769411  Morningside Ave & W 123 St                40.81
# 4769412             9 Ave & W 45 St          40.76019252
# 4769413       E 97 St & Madison Ave            40.787801
# 4769414             E 11 St & 2 Ave          40.73047309
#
#         End Station Longitude  Distance(Miles)  Bike ID   User Type  \
# 4769410           -73.9912551         1.152304    30519  Subscriber
# 4769411           -73.9551508         0.873261    28812  Subscriber
# 4769412           -73.9912551         1.152304    19088  Subscriber
# 4769413            -73.953559         1.541414    26007  Subscriber
# 4769414          -73.98672378         1.640187    29366  Subscriber
#
#          Birth Year  Age  Gender               Start Coordinates  \
# 4769410      1986.0   31       2       40.7734066 , -73.97782542
# 4769411      1980.0   37       2     40.8021174 , -73.9681805305
# 4769412      1986.0   31       1       40.7734066 , -73.97782542
# 4769413      1990.0   27       1  40.7796680901 , -73.9809304476
# 4769414      1996.0   21       2  40.7511838746 , -73.9713871479
#
#                     End Coordinates
# 4769410   40.76019252 , -73.9912551
# 4769411         40.81 , -73.9551508
# 4769412   40.76019252 , -73.9912551
# 4769413      40.787801 , -73.953559
# 4769414  40.73047309 , -73.98672378
# (4769415, 20)

# %%
# Take the Gender Column and Categorize it by Sex
# use map method to create a new column for sex
station_distance['Sex'] = station_distance.Gender.map({0:'unknown', 1:'male', 2:'female'})

# %%
station_distance.tail(2)
station_distance.shape
# Out:
#          Trip Duration  Trip Duration(Minutes)           Start Time  \
# 4769413           1039               17.316667  2017-09-30 23:59:49
# 4769414            621               10.350000  2017-09-30 23:59:52
#
#                    Stop Time  Start Station ID       Start Station Name  \
# 4769413  2017-10-01 00:17:08              3167  Amsterdam Ave & W 73 St
# 4769414  2017-10-01 00:10:13              3462          E 44 St & 2 Ave
#
#         Start Station Latitude Start Station Longitude  End Station ID  \
# 4769413          40.7796680901          -73.9809304476            3336
# 4769414          40.7511838746          -73.9713871479             237
#
#               End Station Name   ...   End Station Longitude Distance(Miles)  \
# 4769413  E 97 St & Madison Ave   ...              -73.953559        1.541414
# 4769414        E 11 St & 2 Ave   ...            -73.98672378        1.640187
#
#          Bike ID   User Type Birth Year  Age  Gender  \
# 4769413    26007  Subscriber     1990.0   27       1
# 4769414    29366  Subscriber     1996.0   21       2
#
#                       Start Coordinates             End Coordinates     Sex
# 4769413  40.7796680901 , -73.9809304476      40.787801 , -73.953559    male
# 4769414  40.7511838746 , -73.9713871479  40.73047309 , -73.98672378  female
#
# [2 rows x 21 columns]
# (4769415, 21)

# %%
df = station_distance
df.tail(2)
df.shape
# Out:
#          Trip Duration  Trip Duration(Minutes)           Start Time  \
# 4769413           1039               17.316667  2017-09-30 23:59:49
# 4769414            621               10.350000  2017-09-30 23:59:52
#
#                    Stop Time  Start Station ID       Start Station Name  \
# 4769413  2017-10-01 00:17:08              3167  Amsterdam Ave & W 73 St
# 4769414  2017-10-01 00:10:13              3462          E 44 St & 2 Ave
#
#         Start Station Latitude Start Station Longitude  End Station ID  \
# 4769413          40.7796680901          -73.9809304476            3336
# 4769414          40.7511838746          -73.9713871479             237
#
#               End Station Name   ...   End Station Longitude Distance(Miles)  \
# 4769413  E 97 St & Madison Ave   ...              -73.953559        1.541414
# 4769414        E 11 St & 2 Ave   ...            -73.98672378        1.640187
#
#          Bike ID   User Type Birth Year  Age  Gender  \
# 4769413    26007  Subscriber     1990.0   27       1
# 4769414    29366  Subscriber     1996.0   21       2
#
#                       Start Coordinates             End Coordinates     Sex
# 4769413  40.7796680901 , -73.9809304476      40.787801 , -73.953559    male
# 4769414  40.7511838746 , -73.9713871479  40.73047309 , -73.98672378  female
#
# [2 rows x 21 columns]
# (4769415, 21)

# %%
df.columns.tolist()
# Out:
# ['Trip Duration',
#  'Trip Duration(Minutes)',
#  'Start Time',
#  'Stop Time',
#  'Start Station ID',
#  'Start Station Name',
#  'Start Station Latitude',
#  'Start Station Longitude',
#  'End Station ID',
#  'End Station Name',
#  'End Station Latitude',
#  'End Station Longitude',
#  'Distance(Miles)',
#  'Bike ID',
#  'User Type',
#  'Birth Year',
#  'Age',
#  'Gender',
#  'Start Coordinates',
#  'End Coordinates',
#  'Sex']

# %%
df = df[['Trip Duration',
 'Trip Duration(Minutes)',
 'Start Time',
 'Stop Time',
 'Start Station ID',
 'Start Station Name',
 'Start Station Latitude',
 'Start Station Longitude',
 'End Station ID',
 'End Station Name',
 'End Station Latitude',
 'End Station Longitude',
 'Distance(Miles)',
 'Bike ID',
 'User Type',
 'Birth Year',
 'Age',
 'Gender',
 'Sex',
 'Start Coordinates',
 'End Coordinates']]

# %%
df.tail(2)
# Out:
#          Trip Duration  Trip Duration(Minutes)           Start Time  \
# 4769413           1039               17.316667  2017-09-30 23:59:49
# 4769414            621               10.350000  2017-09-30 23:59:52
#
#                    Stop Time  Start Station ID       Start Station Name  \
# 4769413  2017-10-01 00:17:08              3167  Amsterdam Ave & W 73 St
# 4769414  2017-10-01 00:10:13              3462          E 44 St & 2 Ave
#
#         Start Station Latitude Start Station Longitude  End Station ID  \
# 4769413          40.7796680901          -73.9809304476            3336
# 4769414          40.7511838746          -73.9713871479             237
#
#               End Station Name             ...              \
# 4769413  E 97 St & Madison Ave             ...
# 4769414        E 11 St & 2 Ave             ...
#
#         End Station Longitude Distance(Miles)  Bike ID   User Type Birth Year  \
# 4769413            -73.953559        1.541414    26007  Subscriber     1990.0
# 4769414          -73.98672378        1.640187    29366  Subscriber     1996.0
#
#          Age  Gender     Sex               Start Coordinates  \
# 4769413   27       1    male  40.7796680901 , -73.9809304476
# 4769414   21       2  female  40.7511838746 , -73.9713871479
#
#                     End Coordinates
# 4769413      40.787801 , -73.953559
# 4769414  40.73047309 , -73.98672378
#
# [2 rows x 21 columns]

# %%
# save df to csv
df.to_csv('Tableau-CitiBike/TripData_2017_Q3.csv', index=False)

# %% [markdown]
# <hr>
# <br>

# %%
# concat q1-q4 csvs

# %% [markdown]
# # Section for aggregate calculations
